# %%
# %%javascript
# $('<div id="toc"></div>').css({position: 'fixed', top: '120px', left: 0}).appendTo(document.body);
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js');

# %% [markdown]
# # Imports

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1" # the GPU on robinson

# %%
from rdflib import Graph, Literal, URIRef, XSD
from rdflib.namespace import RDF, FOAF, SDO, Namespace
import json
import pandas as pd
from tqdm import tqdm, trange
import html
from datetime import datetime
import io
import requests
import hashlib
import re
import urllib.parse


from polyglot.detect import Detector
from polyglot.detect.base import logger as polyglot_logger
polyglot_logger.setLevel("ERROR")


import statistics
import textstat

import torch
import torch.nn as nn
from transformers import BertForPreTraining, AutoTokenizer

# %% [markdown]
# # Utils

# %%
def normalize_text(text):
    text = text.replace('&amp;', '&')
    text = text.replace('\xa0', '')
    text = re.sub(r'http\S+', '', text)
    text = html.unescape(text)
    text = " ".join(text.split())
    return text

def uri_generator(identifier):
    h = hashlib.sha224(str.encode(identifier)).hexdigest()
    
    return str(h)

CONSPIRACIES = ['Suppressed Cures', 'Behaviour and mind Control', 'Antivax', 'Fake virus', 'Intentional Pandemic', 'Harmful Radiation', 'Population Reduction', 'New World Order', 'Satanism']

# %%
start_date = datetime.strptime('2020-01-01', '%Y-%m-%d')
end_date = datetime.strptime('2021-06-30', '%Y-%m-%d')

# %%
SCHEMA = Namespace("http://schema.org/")
CIMPLE = Namespace("http://data.cimple.eu/ontology#")
NIF = Namespace("http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#")
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")

WIKI_prefix = "http://www.wikidata.org/entity/"
DB_prefix = "http://dbpedia.org/ontology/"

prefix = "http://data.cimple.eu/"

# %% [markdown]
# # Data

# %% [markdown]
# ## BirdWatch

# %%
bw_path = '/data/peskine/birdwatch/'

# %%
BW_CR = pd.read_csv(bw_path+'BW_CR_clean_merged.csv')
BW_CR
# Out:
#                   tweetId                                              Tweet  \
# 0     1380985371794796545              Trump won the election by a landslide
# 1     1388990782015692810  DONALD TRUMP WON THE 2020 ELECTION BY A LOT!\n...
# 2     1435755006867673092        President Trump won https://t.co/GnG8zTlSbj
# 3     1402642394483462149  Daily reminder:\n\nDonald J. Trump won the ele...
# 4     1399207201382731777                         Donald J. Trump won BIGLY.
# ...                   ...                                                ...
# 3038  1379458652323639300  246 fully vaccinated Michiganders got COVID-19...
# 3039  1375128381696700419  Weve got our first deportation of the day http...
# 3040  1399934281774899200  Early #FauciEmails show awareness of potential...
# 3041  1391101810073538563  Palestinians chant bomb bomb Tel Aviv from Jud...
# 3042  1391101810073538563  Palestinians chant bomb bomb Tel Aviv from Jud...
#
#                    noteId                                            summary  \
# 0     1382005896901894144  According to numerous independent sources, Tru...
# 1     1389613071895711746  According to numerous independent sources, Tru...
# 2     1436788728794656774  Trump lost and Biden won the 2020 election.   ...
# 3     1403409669570252800  According to numerous independent sources, Tru...
# 4     1400161353084510212  According to numerous independent sources, Tru...
# ...                   ...                                                ...
# 3038  1380365994611335169  As of 4/7/21 1.8 million Michigan residents ha...
# 3039  1375470560810049546  The Toronto Raptors are playing every home gam...
# 3040  1399984720599994371  It is true that there were concerns about enha...
# 3041  1391879804291538948  Claim is clearly backed up with a video showin...
# 3042  1391595447412740099  That's not what they're chanting. It's a frequ...
#
#                              classification  \
# 0     MISINFORMED_OR_POTENTIALLY_MISLEADING
# 1     MISINFORMED_OR_POTENTIALLY_MISLEADING
# 2     MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3     MISINFORMED_OR_POTENTIALLY_MISLEADING
# 4     MISINFORMED_OR_POTENTIALLY_MISLEADING
# ...                                     ...
# 3038  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3039  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3040  MISINFORMED_OR_POTENTIALLY_MISLEADING
# 3041                         NOT_MISLEADING
# 3042  MISINFORMED_OR_POTENTIALLY_MISLEADING
#
#                                                 CR Fact   credibility  \
# 0      ['Donald Trump won the 2020 election, by a lot']  not_credible
# 1      ['Donald Trump won the 2020 election, by a lot']  not_credible
# 2     ['US President Donald Trump has won the 2020 e...  not_credible
# 3     ['US President Donald Trump has won the 2020 e...  not_credible
# 4     ['Donald Trump has won the re-election against...  not_credible
# ...                                                 ...           ...
# 3038  "['Four states have stopped administering the ...     uncertain
# 3039  "['the image shows one of nine parents who reu...  not_credible
# 3040  "['COVID-19 no more lethal than flu there is n...  not_credible
# 3041  "['Video shows Israeli forces attacking mosque...  not_credible
# 3042  "['Video shows Israeli forces attacking mosque...  not_credible
#
#                                               full_text  \
# 0                 Trump won the election by a landslide
# 1     DONALD TRUMP WON THE 2020 ELECTION BY A LOT!\n...
# 2           President Trump won https://t.co/GnG8zTlSbj
# 3     Daily reminder:\n\nDonald J. Trump won the ele...
# 4                            Donald J. Trump won BIGLY.
# ...                                                 ...
# 3038  246 fully vaccinated Michiganders got COVID-19...
# 3039  We’ve got our first deportation of the day htt...
# 3040  Early #FauciEmails show awareness of potential...
# 3041  Palestinians chant “bomb bomb Tel Aviv” from J...
# 3042  Palestinians chant “bomb bomb Tel Aviv” from J...
#
#                                                  CR Doc
# 0                                                   NaN
# 1                                                   NaN
# 2     [{"claim_text": ["US President Donald Trump ha...
# 3     [{"claim_text": ["US President Donald Trump ha...
# 4     [{"claim_text": ["Donald Trump has won the re-...
# ...                                                 ...
# 3038  [{"claim_text": ["Four states have stopped adm...
# 3039                                                NaN
# 3040  [{"claim_text": ["COVID-19 no more lethal than...
# 3041  [{"claim_text": ["Video shows Israeli forces a...
# 3042  [{"claim_text": ["Video shows Israeli forces a...
#
# [3043 rows x 9 columns]

# %%
with open(bw_path+'idtweetVALUES.jsonl', 'r') as j:
    tweets_list = list(j)

tweets_notes = pd.read_csv(bw_path+'notes-00000.tsv', sep='\t')

len(tweets_list), len(tweets_notes)
# Out:
# (10211, 15445)

# %%
tweets_list_timerange = []

for j in tweets_list:
    file = json.loads(j)
    date_str= datetime.strptime(file['created_at'], '%a %b %d %H:%M:%S %z %Y').replace(tzinfo=None) #.strftime('%Y-%m-%d')
    
    if date_str >= start_date and date_str <= end_date:
        tweets_list_timerange.append(file)

len(tweets_list_timerange)
# Out:
# 6563

# %%
df = pd.read_csv(bw_path+'factors.csv')
emotions = df['emotions'].tolist()
biases = df['biases'].tolist()
sentiments = df['sentiments'].tolist()
cons = df['conspiracies'].tolist()
with open(bw_path+"entities.json", "r") as outfile:
    ents = json.load(outfile)
len(df), len(ents)
# Out:
# (6563, 6563)

# %% [markdown]
# ### BW - Graph

# %%
g = Graph()

# %%
for i in trange(0, len(tweets_list_timerange)):
    t = tweets_list_timerange[i]
    tid = t['id']
    
    identifier = 'tweet'+str(tid)
    uri = 'tweet/'+uri_generator(identifier)
    
    g.add((URIRef(prefix+uri), RDF.type, SCHEMA.SocialMediaPosting))
    
    d = datetime.strptime(t['created_at'], '%a %b %d %H:%M:%S %z %Y').replace(tzinfo=None)
    g.add((URIRef(prefix+uri), SCHEMA.dateCreated, Literal(d.strftime('%Y-%m-%d'), datatype=XSD.date)))
    
    text = t['full_text']
    text = normalize_text(text)
    g.add((URIRef(prefix+uri), SCHEMA.text, Literal(text)))
    
    r = measure_readability(text)
    g.add((URIRef(prefix+uri), CIMPLE.readability_score, Literal(r)))
    
    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
    cons_i = json.loads(cons[i])
    for k in range(0, len(cons_i)):
        if cons_i[k] == 1:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
        elif cons_i[k] == 2:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri), SCHEMA.mentions, URIRef(dbpedia_url)))
    
    row = BW_CR[BW_CR['tweetId']==tid]
    
    #BW tweets can have multiple notes (reviews)
    for review in range(0, len(row['noteId'].tolist())):
        
        identifier_review = 'review'+str(row['noteId'].tolist()[review])
        uri_review = 'review/'+uri_generator(identifier_review)

        g.add((URIRef(prefix+uri_review), RDF.type, SCHEMA.Review))
        g.add((URIRef(prefix+uri_review), SCHEMA.itemReviewed, URIRef(prefix+uri)))
        
        rating = row['classification'].tolist()[review]
        uri_rating = 'rating/'+rating.replace(' ', '_').lower()

        g.add((URIRef(prefix+uri_rating), RDF.type, SCHEMA.Rating))
        
        summary = row['summary'].tolist()[review]
        g.add((URIRef(prefix+uri_rating), SCHEMA.ratingExplanation, Literal(summary)))
        g.add((URIRef(prefix+uri_rating), SCHEMA.ratingValue, Literal(rating)))
        
        r = measure_readability(summary)
        g.add((URIRef(prefix+uri_review), CIMPLE.readability_score, Literal(r)))
        
        ents_summary = extract_dbpedia_entities(summary)
        if 'Resources' in ents_summary:
            for ent in ents_summary['Resources']:
                dbpedia_url = ent['@URI']
#                 uri_mention = 'entity/'+uri_generator(dbpedia_url)
#                 dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                

#                 g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#                 e_types = e['@types'].split(',')
#                 for t in e_types:
#                     if "Wikidata" in t:
#                         g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                     if "DBpedia" in t:
#                         g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#                 g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#                 g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

                g.add((URIRef(prefix+uri_review), SCHEMA.mentions, URIRef(dbpedia_url)))

        g.add((URIRef(prefix+uri_review), SCHEMA.reviewRating, URIRef(prefix+uri_rating)))
        
        #matched claim review
        if row['CR Doc'].tolist()[0]==row['CR Doc'].tolist()[0]:
            cr_doc = json.loads(row['CR Doc'].tolist()[review])[0]

            identifier_cr = 'claim-review'+cr_doc['claim_text'][0]+cr_doc['label']+cr_doc['review_url']
            uri_cr = 'claim-review/'+uri_generator(identifier_cr)
            
            g.add((URIRef(prefix+uri), CIMPLE.related, URIRef(prefix+uri_cr)))
            
#             g.add((URIRef(prefix+uri_cr), RDF.type, SCHEMA.ClaimReview))

#             author = cr_doc['fact_checker']['name']
#             website = cr_doc['fact_checker']['website']
#             identifier_author = 'organization'+str(author)
            
#             uri_author = 'organization/'+uri_generator(identifier_author)

#             g.add((URIRef(prefix+uri_author), RDF.type, SCHEMA.Organization))
#             g.add((URIRef(prefix+uri_author), SCHEMA.name, Literal(author)))
#             g.add((URIRef(prefix+uri_author), SCHEMA.url, URIRef(website)))

#             g.add((URIRef(prefix+uri_cr), SCHEMA.author, URIRef(prefix+uri_author)))

#             date = cr_doc['reviews'][0]['date_published']
#             date = datetime.strptime(date, '%Y-%m-%d')
#             g.add((URIRef(prefix+uri_cr), SCHEMA.datePublished, Literal(date, datatype=XSD.date)))

#             url = cr_doc['review_url']
#             url = url.replace(' ', '')
#             g.add((URIRef(prefix+uri_cr), SCHEMA.url, URIRef(url)))

#             language = cr_doc['fact_checker']['language']
#             g.add((URIRef(prefix+uri_cr), SCHEMA.inLanguage, Literal(language)))

#             uri_normalized_rating = 'rating/'+cr_doc['reviews'][0]['label']

#             g.add((URIRef(prefix+uri_normalized_rating), RDF.type, SCHEMA.Rating))
#             g.add((URIRef(prefix+uri_normalized_rating), SCHEMA.ratingValue, Literal(cr_doc['reviews'][0]['label'])))

#             g.add((URIRef(prefix+uri_cr), CIMPLE.normalizedReviewRating, URIRef(prefix+uri_normalized_rating)))

#             uri_original_rating = 'rating/'+uri_generator(cr_doc['reviews'][0]['original_label'])

#             g.add((URIRef(prefix+uri_original_rating), RDF.type, SCHEMA.Rating))
#             g.add((URIRef(prefix+uri_original_rating), SCHEMA.ratingValue, Literal(cr['reviews'][0]['original_label'].replace('_', ' '))))

#             g.add((URIRef(prefix+uri_cr), SCHEMA.reviewRating, URIRef(prefix+uri_original_rating)))


#             claim = cr_doc['claim_text'][0]
#             identifier_claim = 'claim'+claim
#             uri_claim = 'claim/'+uri_generator(identifier_claim)

#             #SCHEMA.Claim has not yet been integrated
#             #This term is proposed for full integration into Schema.org, pending implementation feedback and adoption from applications and websites. 
#             g.add((URIRef(prefix+uri_claim),RDF.type, SCHEMA.Claim))

#             g.add((URIRef(prefix+uri_cr), SCHEMA.itemReviewed, URIRef(prefix+uri_claim)))

#             text_claim = claim
#             text_claim = normalize_text(text_claim)
#             g.add((URIRef(prefix+uri_claim),SCHEMA.text, Literal(text_claim)))
            
#             appearances = cr_doc['appearances']
#             for a in appearances:
#                 identifier_appearance = 'appearance'+str(a)
#                 uri_appearance = 'appearance/'+uri_generator(identifier_appearance)
#                 g.add((URIRef(prefix+uri_appearance), RDF.type, SCHEMA.CreativeWork))
#                 g.add((URIRef(prefix+uri_appearance), SCHEMA.url, URIRef(a)))
#                 g.add((URIRef(prefix+uri_claim), SCHEMA.appearance, URIRef(prefix+uri_appearance)))
                
#             if prefix+uri_cr in d_factors_cr:
#                 factors_cr = d_factors_cr[prefix+uri_cr]

#                 e = factors_cr[1]
#                 if e != 'None':
#                     g.add((URIRef(prefix+uri_claim), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
#                 b = factors_cr[2]
#                 g.add((URIRef(prefix+uri_claim), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
#                 s = factors_cr[3]
#                 g.add((URIRef(prefix+uri_claim), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
#                 cons_i = json.loads(factors_cr[4])
#                 for k in range(0, len(cons_i)):
#                     if cons_i[k] == 1:
#                         c = CONSPIRACIES[k]
#                         g.add((URIRef(prefix+uri_claim), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
#                     elif cons_i[k] == 2:
#                         c = CONSPIRACIES[k]
#                         g.add((URIRef(prefix+uri_claim), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))

#                 entities = factors_cr[0]
#                 if 'Resources' in entities:
#                     for e in entities['Resources']:
#                         dbpedia_url = e['@URI']
# #                         uri_mention = 'entity/'+uri_generator(dbpedia_url)
# #                         dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                

# #                         g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
# #                         e_types = e['@types'].split(',')
# #                         for t in e_types:
# #                             if "Wikidata" in t:
# #                                 g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
# #                             if "DBpedia" in t:
# #                                 g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

# #                         g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
# #                         g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

#                         g.add((URIRef(prefix+uri_claim), SCHEMA.mentions, URIRef(dbpedia_url)))
# Out:
# 100%|███████████████████████████████████████████| 6563/6563 [03:56<00:00, 27.75it/s]

# %%
len(g)
# Out:
# 72932

# %%
g.serialize(destination="/data/peskine/KGs/birdwatch-v3.ttl")
# Out:
# <Graph identifier=N92d07c3e633c437ba3f772d80e1384b8 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## MediaEval

# %%
me_path = '/data/peskine/mediaeval22/'

df_me = pd.read_csv(me_path+'task-1-train-and-test-merged.csv')
df_me
# Out:
#       tweet_id  class_label_for_Suppressed_cures_category  \
# 0            1                                          1
# 1            2                                          1
# 2            3                                          1
# 3            4                                          1
# 4            5                                          1
# ...        ...                                        ...
# 2730     30826                                          1
# 2731     30827                                          1
# 2732     30828                                          1
# 2733     30829                                          1
# 2734     30830                                          1
#
#       class_label_for_Behaviour_and_Mind_Control_category  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 2730                                                  1
# 2731                                                  1
# 2732                                                  1
# 2733                                                  1
# 2734                                                  3
#
#       class_label_for_Antivax_category  class_label_for_Fake_virus_category  \
# 0                                    1                                    3
# 1                                    1                                    1
# 2                                    1                                    3
# 3                                    1                                    1
# 4                                    1                                    1
# ...                                ...                                  ...
# 2730                                 1                                    1
# 2731                                 1                                    1
# 2732                                 1                                    1
# 2733                                 1                                    1
# 2734                                 3                                    1
#
#       class_label_for_Intentional_Pandemic_category  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
# ...                                             ...
# 2730                                              3
# 2731                                              2
# 2732                                              3
# 2733                                              1
# 2734                                              1
#
#       class_label_for_Harmful_Radiation_Influence_category  \
# 0                                                     3
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 2730                                                  1
# 2731                                                  1
# 2732                                                  1
# 2733                                                  1
# 2734                                                  1
#
#       class_label_for_Population_reduction_Control_category  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 2730                                                  3
# 2731                                                  1
# 2732                                                  3
# 2733                                                  1
# 2734                                                  1
#
#       class_label_for_New_World_Order_category  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
# ...                                        ...
# 2730                                         1
# 2731                                         1
# 2732                                         1
# 2733                                         1
# 2734                                         1
#
#       class_label_for_Satanism_category  \
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
# ...                                 ...
# 2730                                  1
# 2731                                  1
# 2732                                  1
# 2733                                  1
# 2734                                  3
#
#                                              tweet_text
# 0     None! But I just saw a very frightening video ...
# 1     How many CV Deaths were 80 yrs or older? Stats...
# 2     Remember this is all based on flawed data! Flu...
# 3     Why did trump believe China over our own Intel...
# 4     There are no more kids in cages there's a push...
# ...                                                 ...
# 2730  If Hillary were president we would have lost o...
# 2731  Can’t believe after all this time people are s...
# 2732  If you believe that all of this chaos and deat...
# 2733  ...what? Qanon isn't "against covid" or "again...
# 2734  Interesting how we are all being prepared for ...
#
# [2735 rows x 11 columns]

# %%
df = pd.read_csv(me_path+'factors.csv')
emotions = df['emotions'].tolist()
biases = df['biases'].tolist()
sentiments = df['sentiments'].tolist()
cons = df['conspiracies'].tolist()
with open(me_path+"entities.json", "r") as outfile:
    ents = json.load(outfile)
len(df), len(ents)
# Out:
# (2735, 2735)

# %% [markdown]
# ### ME - Graph

# %%
g = Graph()

# %%
for i in trange(0, len(df_me)):
    text = df_me["tweet_text"].tolist()[i]
    identifier = 'tweet'+str(text)
    uri = 'tweet/'+uri_generator(identifier)
    
    g.add((URIRef(prefix+uri), RDF.type, SCHEMA.SocialMediaPosting))
    
    text = normalize_text(text)
    g.add((URIRef(prefix+uri), SCHEMA.text, Literal(text)))
    
    r = measure_readability(text)
    g.add((URIRef(prefix+uri), CIMPLE.readability_score, Literal(r)))

    
    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
    gt = df_me.iloc[i,1:10].tolist()
    for c in range(0, 9):
        if gt[c]==2:
            g.add((URIRef(prefix+uri), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+CONSPIRACIES[c].replace(' ', '_'))))
        elif gt[c]==3:
            g.add((URIRef(prefix+uri), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+CONSPIRACIES[c].replace(' ', '_'))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri), SCHEMA.mentions, URIRef(dbpedia_url)))
# Out:
# 100%|██████████████████████████████████████████| 2735/2735 [00:04<00:00, 666.39it/s]

# %%
len(g)
# Out:
# 28745

# %%
g.serialize(destination="/data/peskine/KGs/mediaeval-v3.ttl")
# Out:
# <Graph identifier=Ne3140d6c7cde404e810eeeacac17c20f (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Check-That 2022

# %%
ct_path = '/data/peskine/clef2022-checkthat-lab/task2/'

df_tweets = pd.read_csv(ct_path+'data/subtask-2a--english/'+'tweets-train-dev.tsv', sep='\t',  names=['tweets', 'text'])
df_articles = pd.read_csv(ct_path+'data/subtask-2a--english/'+'filtered_dates_CR_doc.csv')

# %%
df_match_train = pd.read_csv(ct_path+'data/subtask-2a--english/'+'qrels-train.tsv', sep='\t', names=['tweets', '0', 'vclaims', '1'])
df_match_dev = pd.read_csv(ct_path+'data/subtask-2a--english/'+'qrels-dev.tsv', sep='\t', names=['tweets', '0', 'vclaims', '1'])
df_match_full = df_match_train.append(df_match_dev)

# %%
factors_articles = pd.read_csv(ct_path+'articles_factors.csv')
emotions = factors_articles['emotions'].tolist()
biases = factors_articles['biases'].tolist()
sentiments = factors_articles['sentiments'].tolist()
cons = factors_articles['conspiracies'].tolist()
with open(ct_path+"entities_articles.json", "r") as outfile:
    ents_articles = json.load(outfile)
len(factors_articles), len(ents_articles)
# Out:
# (2543, 2543)

# %% [markdown]
# ### CT - Graph

# %%
g = Graph()

# %%
count = 0
for i in trange(0, len(df_articles)):
    row = df_articles.iloc[i, :]
    if row['CR Doc']==row['CR Doc']:
        count+=1
# Out:
# 100%|████████████████████████████████████████| 2543/2543 [00:00<00:00, 10153.20it/s]

# %%
errors = []
for i in trange(0, len(df_articles)):
    row = df_articles.iloc[i, :]
    if row['CR Doc']==row['CR Doc']:
        cr_doc = json.loads(row['CR Doc'])
        identifier = 'claim-review'+cr_doc['claim_text'][0]+cr_doc['label']+cr_doc['review_url']

    else:
        identifier = 'claim-review'+row['vclaim_id']
        uri = 'claim-review/'+uri_generator(identifier)
        g.add((URIRef(prefix+uri), RDF.type, SCHEMA.ClaimReview))

    
        identifier_sno = 'organization/'+'Snopes.com'
        uri_sno = 'organization/'+uri_generator(identifier_sno)
        g.add((URIRef(prefix+uri), SCHEMA.author, URIRef(prefix+uri_sno)))
    
        dateline = row['date']
        if dateline == dateline:
            date = datetime.strptime(dateline, "%Y-%m-%d") 
            g.add((URIRef(prefix+uri), SCHEMA.dateline, Literal(date.strftime('%Y-%m-%d'), datatype=XSD.date)))
        
        vclaim = row['vclaim']
        if vclaim==vclaim:        
            identifier_vclaim = 'claim'+str(vclaim)
            uri_vclaim = 'claim/'+uri_generator(identifier_vclaim)
            vclaim = normalize_text(vclaim)
            g.add((URIRef(prefix+uri_vclaim), RDF.type, SCHEMA.Claim))
            g.add((URIRef(prefix+uri_vclaim), SCHEMA.text, Literal(vclaim)))

            g.add((URIRef(prefix+uri), SCHEMA.itemReviewed, URIRef(prefix+uri_vclaim)))

            r = measure_readability(vclaim)
            g.add((URIRef(prefix+uri_vclaim), CIMPLE.readability_score, Literal(r)))
    
    
    headline = row['title']
    if headline==headline:
        headline = normalize_text(headline)
        g.add((URIRef(prefix+uri), SCHEMA.headline, Literal(headline)))
            
    body = row['subtitle']
    if body==body:
        body = normalize_text(body)
        g.add((URIRef(prefix+uri), SCHEMA.alternativeHeadline, Literal(body)))
    
    r = measure_readability(headline+'\n'+body)
    g.add((URIRef(prefix+uri), CIMPLE.readability_score, Literal(r)))

    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
    cons_i = json.loads(cons[i])
    for k in range(0, len(cons_i)):
        if cons_i[k] == 1:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
        elif cons_i[k] == 2:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri), SCHEMA.mentions, URIRef(dbpedia_url)))

#     if row['CR Doc']==row['CR Doc']:
#         cr_doc = json.loads(row['CR Doc'])
        
#         author = cr_doc['fact_checker']['name']
#         website = cr_doc['fact_checker']['website']
#         identifier_author = 'organization'+str(author)
#         uri_author = 'organization/'+uri_generator(identifier_author)

#         g.add((URIRef(prefix+uri_author), RDF.type, SCHEMA.Organization))
#         g.add((URIRef(prefix+uri_author), SCHEMA.name, Literal(author)))
#         g.add((URIRef(prefix+uri_author), SCHEMA.url, URIRef(website)))

#         g.add((URIRef(prefix+uri), SCHEMA.author, URIRef(prefix+uri_author)))

#         date = cr_doc['reviews'][0]['date_published']
#         date = datetime.strptime(date, '%Y-%m-%d')
#         g.add((URIRef(prefix+uri), SCHEMA.datePublished, Literal(date, datatype=XSD.date)))

#         url = cr_doc['review_url']
#         url = url.replace(' ', '')
#         g.add((URIRef(prefix+uri), SCHEMA.url, URIRef(url)))

#         language = cr_doc['fact_checker']['language']
#         g.add((URIRef(prefix+uri), SCHEMA.inLanguage, Literal(language)))

#         uri_normalized_rating = 'rating/'+cr_doc['reviews'][0]['label']

#         g.add((URIRef(prefix+uri_normalized_rating), RDF.type, SCHEMA.Rating))
#         g.add((URIRef(prefix+uri_normalized_rating), SCHEMA.ratingValue, Literal(cr_doc['reviews'][0]['label'])))

#         g.add((URIRef(prefix+uri), CIMPLE.normalizedReviewRating, URIRef(prefix+uri_normalized_rating)))

#         uri_original_rating = 'rating/'+uri_generator(cr_doc['reviews'][0]['original_label'])

#         g.add((URIRef(prefix+uri_original_rating), RDF.type, SCHEMA.Rating))
#         g.add((URIRef(prefix+uri_original_rating), SCHEMA.ratingValue, Literal(cr['reviews'][0]['original_label'].replace('_', ' '))))

#         g.add((URIRef(prefix+uri), SCHEMA.reviewRating, URIRef(prefix+uri_original_rating)))


#         claim = cr_doc['claim_text'][0]
#         identifier_claim = 'claim'+claim
#         uri_claim = 'claim/'+uri_generator(identifier_claim)

#         #SCHEMA.Claim has not yet been integrated
#         #This term is proposed for full integration into Schema.org, pending implementation feedback and adoption from applications and websites. 
#         g.add((URIRef(prefix+uri_claim),RDF.type, SCHEMA.Claim))
        
#         text_claim = claim
#         text_claim = normalize_text(text_claim)
#         g.add((URIRef(prefix+uri_claim),SCHEMA.text, Literal(text_claim)))

#         g.add((URIRef(prefix+uri), SCHEMA.itemReviewed, URIRef(prefix+uri_claim)))

#         appearances = cr_doc['appearances']
#         for a in appearances:
#             identifier_appearance = 'appearance'+str(a)
#             uri_appearance = 'appearance/'+uri_generator(identifier_appearance)
#             g.add((URIRef(prefix+uri_appearance), RDF.type, SCHEMA.CreativeWork))
#             g.add((URIRef(prefix+uri_appearance), SCHEMA.url, URIRef(a)))
#             g.add((URIRef(prefix+uri_claim), SCHEMA.appearance, URIRef(prefix+uri_appearance)))

#         if prefix+uri in d_factors_cr:
#             factors_cr = d_factors_cr[prefix+uri_cr]

#             e = factors_cr[1]
#             if e != 'None':
#                 g.add((URIRef(prefix+uri_claim), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
#             b = factors_cr[2]
#             g.add((URIRef(prefix+uri_claim), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
#             s = factors_cr[3]
#             g.add((URIRef(prefix+uri_claim), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
#             cons_i = json.loads(factors_cr[4])
#             for k in range(0, len(cons_i)):
#                 if cons_i[k] == 1:
#                     c = CONSPIRACIES[k]
#                     g.add((URIRef(prefix+uri_claim), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
#                 elif cons_i[k] == 2:
#                     c = CONSPIRACIES[k]
#                     g.add((URIRef(prefix+uri_claim), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))

#             entities = factors_cr[0]
#             if 'Resources' in entities:
#                 for e in entities['Resources']:
#                     dbpedia_url = e['@URI']
# #                     uri_mention = 'entity/'+uri_generator(dbpedia_url)
# #                     dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                

# #                     g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
# #                     e_types = e['@types'].split(',')
# #                     for t in e_types:
# #                         if "Wikidata" in t:
# #                             g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
# #                         if "DBpedia" in t:
# #                             g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

# #                     g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
# #                     g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

#                     g.add((URIRef(prefix+uri_claim), SCHEMA.mentions, URIRef(dbpedia_url)))
# Out:
# 100%|█████████████████████████████████████████| 2543/2543 [00:02<00:00, 1213.90it/s]

# %%
factors_tweets = pd.read_csv(ct_path+'tweets_factors.csv')
emotions = factors_tweets['emotions'].tolist()
biases = factors_tweets['biases'].tolist()
sentiments = factors_tweets['sentiments'].tolist()
cons = factors_tweets['conspiracies'].tolist()
with open(ct_path+"entities_tweets.json", "r") as outfile:
    ents_tweets = json.load(outfile)
len(factors_tweets), len(ents_tweets)
# Out:
# (1199, 1199)

# %%
errors = []
for i in trange(0, len(df_tweets)):
        
    text = df_tweets['text'].tolist()[i]
    identifier = 'tweet'+text
    uri = 'tweet/'+uri_generator(identifier)
    g.add((URIRef(prefix+uri), RDF.type, SCHEMA.SocialMediaPosting))
    
    text=normalize_text(text)
    g.add((URIRef(prefix+uri), SCHEMA.text, Literal(text)))
    
    r = measure_readability(text)
    g.add((URIRef(prefix+uri), CIMPLE.readability_score, Literal(r)))
        
    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasBias, URIRef(prefix+'bias/'+str(b.lower()))))
    cons_i = json.loads(cons[i])
    for k in range(0, len(cons_i)):
        if cons_i[k] == 1:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
        elif cons_i[k] == 2:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri), SCHEMA.mentions, URIRef(dbpedia_url)))
    
    
    tweet_id = df_tweets['tweets'].tolist()[i]
    matches = df_match_full[df_match_full['tweets']==tweet_id]['vclaims'].tolist()
    for m in matches:
        row = df_articles[df_articles['vclaim_id']==m]
        if len(row)>0:
            if row['CR Doc'].tolist()[0]==row['CR Doc'].tolist()[0]:
                cr_doc = json.loads(row['CR Doc'].tolist()[0])
                identifier_article = 'claim-review'+cr_doc['claim_text'][0]+cr_doc['label']+cr_doc['review_url']
            else:
                identifier_article = 'claim-review'+row['vclaim_id']

            uri_article = 'claim-review/'+uri_generator(identifier_article)
            
            g.add((URIRef(prefix+uri), CIMPLE.related, URIRef(prefix+uri_article)))
# Out:
# 100%|██████████████████████████████████████████| 1196/1196 [00:02<00:00, 562.86it/s]

# %%
len(g)
# Out:
# 21859

# %%
g.serialize(destination="/data/peskine/KGs/check-that-v3.ttl")
# Out:
# <Graph identifier=N10e0bb02946a4685b6351255cb911d6d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## AFP

# %%
afp_path = '/data/peskine/AFP/'
df_afp = pd.read_csv(afp_path+'/AFP.csv')
df_afp
# Out:
# /home/semantic/.conda/envs/peskine-pytorch/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ProviderId            DateId    NewsItemId  RevisionId  \
# 0         afp.com  20200505T190606Z  TX-PAR-KZM80           1
# 1         afp.com  20200505T205404Z  TX-PAR-KZO17           1
# 2         afp.com  20200505T115036Z  TX-PAR-KZE46           1
# 3         afp.com  20200505T140217Z  TX-PAR-KZG96           1
# 4         afp.com  20200505T085721Z  TX-PAR-KZB30           1
# ...           ...               ...           ...         ...
# 252456    afp.com  20210127T093921Z  TX-PAR-SRO59           1
# 252457    afp.com  20210127T095533Z  TX-PAR-SRO83           1
# 252458    afp.com  20210127T183628Z  TX-PAR-SSD41           1
# 252459    afp.com  20210127T175934Z  TX-PAR-SSC35           1
# 252460    afp.com  20210127T174715Z  TX-PAR-SSB98           1
#
#                                          PublicIdentifier  NewsItemType  \
# 0       urn:newsml:afp.com:20200505T190606Z:TX-PAR-KZM...           NaN
# 1       urn:newsml:afp.com:20200505T205404Z:TX-PAR-KZO...           NaN
# 2       urn:newsml:afp.com:20200505T115036Z:TX-PAR-KZE...           NaN
# 3       urn:newsml:afp.com:20200505T140217Z:TX-PAR-KZG...           NaN
# 4       urn:newsml:afp.com:20200505T085721Z:TX-PAR-KZB...           NaN
# ...                                                   ...           ...
# 252456  urn:newsml:afp.com:20210127T093921Z:TX-PAR-SRO...           NaN
# 252457  urn:newsml:afp.com:20210127T095533Z:TX-PAR-SRO...           NaN
# 252458  urn:newsml:afp.com:20210127T183628Z:TX-PAR-SSD...           NaN
# 252459  urn:newsml:afp.com:20210127T175934Z:TX-PAR-SSC...           NaN
# 252460  urn:newsml:afp.com:20210127T174715Z:TX-PAR-SSB...           NaN
#
#                 FirstCreated   ThisRevisionCreated  Status  Urgency  \
# 0       20200505T190606+0000  20200505T190606+0000     NaN      NaN
# 1       20200505T205404+0000  20200505T205404+0000     NaN      NaN
# 2       20200505T115036+0000  20200505T115036+0000     NaN      NaN
# 3       20200505T140217+0000  20200505T140217+0000     NaN      NaN
# 4       20200505T085721+0000  20200505T085721+0000     NaN      NaN
# ...                      ...                   ...     ...      ...
# 252456  20210127T093921+0000  20210127T093921+0000     NaN      NaN
# 252457  20210127T095533+0000  20210127T095533+0000     NaN      NaN
# 252458  20210127T183628+0000  20210127T183628+0000     NaN      NaN
# 252459  20210127T175934+0000  20210127T175934+0000     NaN      NaN
# 252460  20210127T174715+0000  20210127T174715+0000     NaN      NaN
#
#         AssociatedWith                          DateLine  \
# 0                  NaN     Monrovia, May 5, 2020 (AFP) -
# 1                  NaN        Paris, May 5, 2020 (AFP) -
# 2                  NaN     Brussels, May 5, 2020 (AFP) -
# 3                  NaN      Beijing, May 5, 2020 (AFP) -
# 4                  NaN    Hong Kong, May 5, 2020 (AFP) -
# ...                ...                               ...
# 252456             NaN      Sydney, Jan 27, 2021 (AFP) -
# 252457             NaN       Paris, Jan 27, 2021 (AFP) -
# 252458             NaN    New York, Jan 27, 2021 (AFP) -
# 252459             NaN     Yaoundé, Jan 27, 2021 (AFP) -
# 252460             NaN  Washington, Jan 27, 2021 (AFP) -
#
#                                                  HeadLine Creator  Language  \
# 0                  Several dead in Liberian mine collapse     NaN       NaN
# 1       Tennis establishes virus player fund, raises $...     NaN       NaN
# 2       Brussels asserts primacy of EU law after Germa...     NaN       NaN
# 3       China says launch of key new space rocket 'suc...     NaN       NaN
# 4       Hong Kong to lift major social restrictions as...     NaN       NaN
# ...                                                   ...     ...       ...
# 252456  Australia ordered to pay migrants for privacy ...     NaN       NaN
# 252457  Napoleon's account of legendary Battle of Aust...     NaN       NaN
# 252458  US Open revives qualifying for showdown at Tor...     NaN       NaN
# 252459                    53 killed in Cameroon bus blaze     NaN       NaN
# 252460  US issues terror alert over anti-government ex...     NaN       NaN
#
#                                              SubjectCodes  \
# 0       ['04012005', '03013000', '04012000', '04000000...
# 1                    ['15065000', '15000000', '15000000']
# 2       ['04008001', '11002000', '04008020', '11013000...
# 3        ['13008000', '13007000', '13006000', '13000000']
# 4        ['07000000', '07001002', '07001001', '07001000']
# ...                                                   ...
# 252456  ['02007001', '11007000', '02006000', '11000000...
# 252457  ['10000000', '13003002', '16009000', '01000000...
# 252458               ['15027000', '15000000', '15000000']
# 252459  ['03013000', '04015000', '04000000', '04000000...
# 252460               ['11000000', '16003000', '16000000']
#
#                                                  Keywords  \
# 0                       ['Liberia', 'mining', 'accident']
# 1       ['tennis', 'health', 'virus', 'ATP', 'WTA', 'I...
# 2       ['ECB', 'eurozone', 'economy', 'Germany', 'cou...
# 3                            ['China', 'space', 'launch']
# 4           ['Health', 'virus', 'HongKong', 'Carrie Lam']
# ...                                                   ...
# 252456                     ['Australia', 'law', 'rights']
# 252457  ['France', 'history', 'Napoleon', 'Napoleon Bo...
# 252458                   ['Golf', 'USPGA', 'Open', 'USA']
# 252459       ['Cameroon', 'accident', 'transport', 'bus']
# 252460              ['US', 'politics', 'unrest', 'alert']
#
#                                            FirstParagraph  \
# 0       Up to 50 people have died in a mine collapse i...
# 1       A fund for tennis players hardest hit by the c...
# 2       The EU insisted that European law trumps that ...
# 3       China on Tuesday successfully launched a new r...
# 4       Hong Kong on Tuesday announced plans to ease m...
# ...                                                   ...
# 252456  An Australian watchdog on Wednesday ordered th...
# 252457  Napoleon Bonaparte's account of his victory at...
# 252458  The US Open will return to a qualifying format...
# 252459  Fifty-three people died Wednesday when a bus c...
# 252460  The US Department of Homeland Security declare...
#
#                                                      Body  \
# 0       \nUp to 50 people have died in a mine collapse...
# 1       \nA fund for tennis players hardest hit by the...
# 2       \nThe EU insisted that European law trumps tha...
# 3       \nChina on Tuesday successfully launched a new...
# 4       \nHong Kong on Tuesday announced plans to ease...
# ...                                                   ...
# 252456  \nAn Australian watchdog on Wednesday ordered ...
# 252457  \nNapoleon Bonaparte's account of his victory ...
# 252458  \nThe US Open will return to a qualifying form...
# 252459  \nFifty-three people died Wednesday when a bus...
# 252460  \nThe US Department of Homeland Security decla...
#
#                                                  Location
# 0              [['Country', 'LBR'], ['City', 'Monrovia']]
# 1                 [['Country', 'FRA'], ['City', 'Paris']]
# 2              [['Country', 'BEL'], ['City', 'Brussels']]
# 3               [['Country', 'CHN'], ['City', 'Beijing']]
# 4             [['Country', 'CHN'], ['City', 'Hong Kong']]
# ...                                                   ...
# 252456           [['Country', 'AUS'], ['City', 'Sydney']]
# 252457            [['Country', 'FRA'], ['City', 'Paris']]
# 252458  [['Country', 'USA'], ['Area', 'State of New Yo...
# 252459  [['Country', 'CMR'], ['Area', 'Région du Centr...
# 252460  [['Country', 'USA'], ['Area', 'District of Col...
#
# [252461 rows x 20 columns]

# %%
dates = df_afp['DateId']
dates = [datetime.strptime(d[:8], "%Y%m%d") for d in dates]
df_afp['dates'] = dates
df_afp['dates']
# Out:
# 0        2020-05-05
# 1        2020-05-05
# 2        2020-05-05
# 3        2020-05-05
# 4        2020-05-05
#             ...
# 252456   2021-01-27
# 252457   2021-01-27
# 252458   2021-01-27
# 252459   2021-01-27
# 252460   2021-01-27
# Name: dates, Length: 252461, dtype: datetime64[ns]

# %%
df_afp = df_afp.loc[(df_afp['dates'] >= start_date) & (df_afp['dates'] <= end_date)]
df_afp
# Out:
#        ProviderId            DateId    NewsItemId  RevisionId  \
# 0         afp.com  20200505T190606Z  TX-PAR-KZM80           1
# 1         afp.com  20200505T205404Z  TX-PAR-KZO17           1
# 2         afp.com  20200505T115036Z  TX-PAR-KZE46           1
# 3         afp.com  20200505T140217Z  TX-PAR-KZG96           1
# 4         afp.com  20200505T085721Z  TX-PAR-KZB30           1
# ...           ...               ...           ...         ...
# 252456    afp.com  20210127T093921Z  TX-PAR-SRO59           1
# 252457    afp.com  20210127T095533Z  TX-PAR-SRO83           1
# 252458    afp.com  20210127T183628Z  TX-PAR-SSD41           1
# 252459    afp.com  20210127T175934Z  TX-PAR-SSC35           1
# 252460    afp.com  20210127T174715Z  TX-PAR-SSB98           1
#
#                                          PublicIdentifier  NewsItemType  \
# 0       urn:newsml:afp.com:20200505T190606Z:TX-PAR-KZM...           NaN
# 1       urn:newsml:afp.com:20200505T205404Z:TX-PAR-KZO...           NaN
# 2       urn:newsml:afp.com:20200505T115036Z:TX-PAR-KZE...           NaN
# 3       urn:newsml:afp.com:20200505T140217Z:TX-PAR-KZG...           NaN
# 4       urn:newsml:afp.com:20200505T085721Z:TX-PAR-KZB...           NaN
# ...                                                   ...           ...
# 252456  urn:newsml:afp.com:20210127T093921Z:TX-PAR-SRO...           NaN
# 252457  urn:newsml:afp.com:20210127T095533Z:TX-PAR-SRO...           NaN
# 252458  urn:newsml:afp.com:20210127T183628Z:TX-PAR-SSD...           NaN
# 252459  urn:newsml:afp.com:20210127T175934Z:TX-PAR-SSC...           NaN
# 252460  urn:newsml:afp.com:20210127T174715Z:TX-PAR-SSB...           NaN
#
#                 FirstCreated   ThisRevisionCreated  Status  Urgency  ...  \
# 0       20200505T190606+0000  20200505T190606+0000     NaN      NaN  ...
# 1       20200505T205404+0000  20200505T205404+0000     NaN      NaN  ...
# 2       20200505T115036+0000  20200505T115036+0000     NaN      NaN  ...
# 3       20200505T140217+0000  20200505T140217+0000     NaN      NaN  ...
# 4       20200505T085721+0000  20200505T085721+0000     NaN      NaN  ...
# ...                      ...                   ...     ...      ...  ...
# 252456  20210127T093921+0000  20210127T093921+0000     NaN      NaN  ...
# 252457  20210127T095533+0000  20210127T095533+0000     NaN      NaN  ...
# 252458  20210127T183628+0000  20210127T183628+0000     NaN      NaN  ...
# 252459  20210127T175934+0000  20210127T175934+0000     NaN      NaN  ...
# 252460  20210127T174715+0000  20210127T174715+0000     NaN      NaN  ...
#
#                                 DateLine  \
# 0          Monrovia, May 5, 2020 (AFP) -
# 1             Paris, May 5, 2020 (AFP) -
# 2          Brussels, May 5, 2020 (AFP) -
# 3           Beijing, May 5, 2020 (AFP) -
# 4         Hong Kong, May 5, 2020 (AFP) -
# ...                                  ...
# 252456      Sydney, Jan 27, 2021 (AFP) -
# 252457       Paris, Jan 27, 2021 (AFP) -
# 252458    New York, Jan 27, 2021 (AFP) -
# 252459     Yaoundé, Jan 27, 2021 (AFP) -
# 252460  Washington, Jan 27, 2021 (AFP) -
#
#                                                  HeadLine Creator Language  \
# 0                  Several dead in Liberian mine collapse     NaN      NaN
# 1       Tennis establishes virus player fund, raises $...     NaN      NaN
# 2       Brussels asserts primacy of EU law after Germa...     NaN      NaN
# 3       China says launch of key new space rocket 'suc...     NaN      NaN
# 4       Hong Kong to lift major social restrictions as...     NaN      NaN
# ...                                                   ...     ...      ...
# 252456  Australia ordered to pay migrants for privacy ...     NaN      NaN
# 252457  Napoleon's account of legendary Battle of Aust...     NaN      NaN
# 252458  US Open revives qualifying for showdown at Tor...     NaN      NaN
# 252459                    53 killed in Cameroon bus blaze     NaN      NaN
# 252460  US issues terror alert over anti-government ex...     NaN      NaN
#
#                                              SubjectCodes  \
# 0       ['04012005', '03013000', '04012000', '04000000...
# 1                    ['15065000', '15000000', '15000000']
# 2       ['04008001', '11002000', '04008020', '11013000...
# 3        ['13008000', '13007000', '13006000', '13000000']
# 4        ['07000000', '07001002', '07001001', '07001000']
# ...                                                   ...
# 252456  ['02007001', '11007000', '02006000', '11000000...
# 252457  ['10000000', '13003002', '16009000', '01000000...
# 252458               ['15027000', '15000000', '15000000']
# 252459  ['03013000', '04015000', '04000000', '04000000...
# 252460               ['11000000', '16003000', '16000000']
#
#                                                  Keywords  \
# 0                       ['Liberia', 'mining', 'accident']
# 1       ['tennis', 'health', 'virus', 'ATP', 'WTA', 'I...
# 2       ['ECB', 'eurozone', 'economy', 'Germany', 'cou...
# 3                            ['China', 'space', 'launch']
# 4           ['Health', 'virus', 'HongKong', 'Carrie Lam']
# ...                                                   ...
# 252456                     ['Australia', 'law', 'rights']
# 252457  ['France', 'history', 'Napoleon', 'Napoleon Bo...
# 252458                   ['Golf', 'USPGA', 'Open', 'USA']
# 252459       ['Cameroon', 'accident', 'transport', 'bus']
# 252460              ['US', 'politics', 'unrest', 'alert']
#
#                                            FirstParagraph  \
# 0       Up to 50 people have died in a mine collapse i...
# 1       A fund for tennis players hardest hit by the c...
# 2       The EU insisted that European law trumps that ...
# 3       China on Tuesday successfully launched a new r...
# 4       Hong Kong on Tuesday announced plans to ease m...
# ...                                                   ...
# 252456  An Australian watchdog on Wednesday ordered th...
# 252457  Napoleon Bonaparte's account of his victory at...
# 252458  The US Open will return to a qualifying format...
# 252459  Fifty-three people died Wednesday when a bus c...
# 252460  The US Department of Homeland Security declare...
#
#                                                      Body  \
# 0       \nUp to 50 people have died in a mine collapse...
# 1       \nA fund for tennis players hardest hit by the...
# 2       \nThe EU insisted that European law trumps tha...
# 3       \nChina on Tuesday successfully launched a new...
# 4       \nHong Kong on Tuesday announced plans to ease...
# ...                                                   ...
# 252456  \nAn Australian watchdog on Wednesday ordered ...
# 252457  \nNapoleon Bonaparte's account of his victory ...
# 252458  \nThe US Open will return to a qualifying form...
# 252459  \nFifty-three people died Wednesday when a bus...
# 252460  \nThe US Department of Homeland Security decla...
#
#                                                  Location      dates
# 0              [['Country', 'LBR'], ['City', 'Monrovia']] 2020-05-05
# 1                 [['Country', 'FRA'], ['City', 'Paris']] 2020-05-05
# 2              [['Country', 'BEL'], ['City', 'Brussels']] 2020-05-05
# 3               [['Country', 'CHN'], ['City', 'Beijing']] 2020-05-05
# 4             [['Country', 'CHN'], ['City', 'Hong Kong']] 2020-05-05
# ...                                                   ...        ...
# 252456           [['Country', 'AUS'], ['City', 'Sydney']] 2021-01-27
# 252457            [['Country', 'FRA'], ['City', 'Paris']] 2021-01-27
# 252458  [['Country', 'USA'], ['Area', 'State of New Yo... 2021-01-27
# 252459  [['Country', 'CMR'], ['Area', 'Région du Centr... 2021-01-27
# 252460  [['Country', 'USA'], ['Area', 'District of Col... 2021-01-27
#
# [193933 rows x 21 columns]

# %%
df = pd.read_csv(afp_path+'factors.csv')
emotions = df['emotions'].tolist()
biases = df['biases'].tolist()
sentiments = df['sentiments'].tolist()
cons = df['conspiracies'].tolist()
with open(afp_path+"entities.json", "r") as outfile:
    ents = json.load(outfile)
len(df), len(ents), len(df_afp)
# Out:
# (193933, 193933, 193933)

# %% [markdown]
# ### AFP - Graph

# %%
g = Graph()

# %%
for i in trange(0, len(df_afp)):
    
    row = df_afp.iloc[i, :]
    
    identifier = 'news-article'+str(row['PublicIdentifier'])
    uri = 'news-article'+uri_generator(identifier)
    g.add((URIRef(prefix+uri), RDF.type, SCHEMA.NewsArticle))
    
    identifier_afp = 'organization'+'AFP'
    uri_afp = 'organization/'+uri_generator(identifier_afp)
    g.add((URIRef(prefix+uri), SCHEMA.author, URIRef(prefix+uri_afp)))
    
    date = datetime.strptime(row['DateId'][:8], "%Y%m%d")
    if date == date:
        g.add((URIRef(prefix+uri), SCHEMA.dateline, Literal(date.strftime('%Y-%m-%d'), datatype=XSD.date)))
    
    headline = row['HeadLine']
    if headline==headline:
        if "News Advisory" not in headline:
            headline=normalize_text(headline)
            g.add((URIRef(prefix+uri), SCHEMA.headline, Literal(headline)))
    else:
        headline=""
        
    body = row['Body']
    if body==body:
        body = normalize_text(body)
        g.add((URIRef(prefix+uri), SCHEMA.articleBody, Literal(body)))
    else:
        body = ""
        
    r = measure_readability(headline+'\n'+body)
    g.add((URIRef(prefix+uri), CIMPLE.readability_score, Literal(r)))
        
    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
    cons_i = json.loads(cons[i])
    for k in range(0, len(cons_i)):
        if cons_i[k] == 1:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
        elif cons_i[k] == 2:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri), SCHEMA.mentions, URIRef(dbpedia_url)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/tmp/ipykernel_2399956/2930711967.py in <module>
# ----> 1 for i in trange(0, len(df_afp)):
#       2
#       3     row = df_afp.iloc[i, :]
#       4
#       5     identifier = 'news-article'+str(row['PublicIdentifier'])
#
# NameError: name 'df_afp' is not defined

# %%
len(g)
# Out:
# 7409318

# %%
g.serialize(destination="/data/peskine/KGs/AFP-v2.ttl")
# Out:
# <Graph identifier=N87888a9667e449d2a002efe4604f10a4 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Claim Reviews

# %%
cr_path = '/data/peskine/ClaimReviews20230510/'
claim_reviews_full = json.load(io.open(cr_path+'claim_reviews.json'))

claim_reviews_full
# Out:
# [{'claim_text': ['Misleading claim circulates in South Korea that military mail-in ballots for US presidential election found in a dumpster in PA were all cast for Trump'],
#   'label': 'not_verifiable',
#   'review_url': 'https://factcheck.afp.com/korean-social-media-posts-share-misleading-claim-about-ballots-found-trash-pennsylvania',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/permalink.php?id=100001539747977&story_fbid=3636842506377038'],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Missing context',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '2.5',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Missing context'},
#     'retrieved_by': None,
#     'date_published': '2020-11-13'}]},
#  {'claim_text': ['Los políticos de la UE, que cobran 10.000 euros mensuales, celebran bailando cuando las facturas de energía se disparan 500%'],
#   'label': 'not_credible',
#   'review_url': 'https://factual.afp.com/doc.afp.com.32HV3UX',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://twitter.com/vive_skorzeny/status/1565814232087760896'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2022-09-07'}]},
#  {'claim_text': ['Predsednik Francuske podnosi ostavku zbog hitne istrage za "izdaju"'],
#   'label': 'not_credible',
#   'review_url': 'https://cinjenice.afp.com/doc.afp.com.32EB9RU',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/photo?fbid=467483915379121&set=a.108779461249570'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Netačno',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Netačno'},
#     'retrieved_by': None,
#     'date_published': '2022-07-13'}]},
#  {'claim_text': ['Anthony Fauci fue arrestado por Fuerzas Especiales de EE.UU'],
#   'label': 'not_credible',
#   'review_url': 'https://colombiacheck.com/chequeos/el-doctor-anthony-fauci-no-fue-arrestado-por-las-fuerzas-especiales-de-estados-unidos',
#   'fact_checker': {'name': 'Colombiacheck',
#    'country': 'Colombia',
#    'language': 'Spanish',
#    'website': 'https://colombiacheck.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/colombiacheck',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/colombiacheck_logo.png?v=1674592828',
#    'domain': 'colombiacheck.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2022-04-28'}]},
#  {'claim_text': ['कर्नाटक पुलिस ने बुर्काधारी प्रदर्शनकारियों को गिरफ्तार करना शुरू किया तो पता चला कि इनमें से 40 प्रतिशत लड़के हैं, जो महिला के भेष में बवाल कर रहे हैं.'],
#   'label': 'not_credible',
#   'review_url': 'https://newschecker.in/hi/fact-check-hi/this-burqa-clad-man-has-no-relation-with-karnataka-hijab-row/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://twitter.com/PNRai1/status/1495607024381751296'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading/Partly False',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Misleading/Partly False',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2022-02-22'}]},
#  {'claim_text': ['Rachel Maddow tweeted that Hillary Clinton died in 2016.'],
#   'label': 'not_credible',
#   'review_url': 'http://checkyourfact.com/2021/05/13/fact-check-rachel-maddow-tweet-hillary-clinton-died-2016/',
#   'fact_checker': {'name': 'Check Your Fact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://checkyourfact.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/check-your-fact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/check-your-fact_logo.png?v=1674592972',
#    'domain': 'checkyourfact.com'},
#   'appearances': ['https://www.instagram.com/p/COZ-X4IA1lo'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '3',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2021-05-13'}]},
#  {'claim_text': ['منح مساعدات مصرية للولايات المتحدة في العام 1944'],
#   'label': 'not_credible',
#   'review_url': 'https://factual.afp.com/ar/NotanAgreementCairoAndWashington4-21',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'خطأ',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'خطأ'},
#     'retrieved_by': None,
#     'date_published': '2021-04-06'}]},
#  {'claim_text': ['Animované video zosmiešňujúce Ukrajinu pochádza z vysielania ukrajinskej televízie INN'],
#   'label': 'not_credible',
#   'review_url': 'https://fakty.afp.com/doc.afp.com.32M73QM',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/1942351935794365/videos/607642991099740'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Nepravda',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Nepravda'},
#     'retrieved_by': None,
#     'date_published': '2022-10-27'}]},
#  {'claim_text': ['Atacan al periodista mexicano Rafael Loret de Mola'],
#   'label': 'not_credible',
#   'review_url': 'https://factual.afp.com/doc.afp.com.9XR9FL',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/476634732735473/posts/1591527211246214'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2022-02-02'}]},
#  {'claim_text': ['«\xa0Il se fait injecter de la mélanine pour devenir noir\xa0».'],
#   'label': 'not_credible',
#   'review_url': 'http://africacheck.org/fr/fact-checks/articles/non-personne-ne-peut-sinjecter-de-la-melanine-pour-devenir-noir',
#   'fact_checker': {'name': 'Africa Check',
#    'country': 'South Africa',
#    'language': 'English',
#    'website': 'https://africacheck.org/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/africa-check',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/africa-check_logo.png?v=1529429860',
#    'domain': 'africacheck.org'},
#   'appearances': ['http://www.buzzsenegal.com/news/News/il-se-fait-des-injections-de-melanine-po_n_43785.html'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Incorrect',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'alternateName': 'Incorrect',
#      'bestRating': '6',
#      'worstRating': '1'},
#     'retrieved_by': None,
#     'date_published': '2020-01-26'}]},
#  {'claim_text': ['Fotos provam que o governador de São Paulo, João Doria, tomou a "vacina chinesa" contra a COVID-19 antes de testar positivo para o novo coronavírus'],
#   'label': 'not_credible',
#   'review_url': 'https://checamos.afp.com/imagens-mostram-joao-doria-tomando-vacina-contra-gripe-nao-contra-covid-19',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/juliohubnerbh/photos/a.1201906466527479/3416782018373235?theater=&type=3'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2020-08-13'}]},
#  {'claim_text': ['Ketchup, orange squash, tomatoes, strawberries and grapes all deliver positive Covid-19 lateral flow test results.'],
#   'label': 'not_verifiable',
#   'review_url': 'https://fullfact.org/online/ketchup-squash-fruit/',
#   'fact_checker': {'name': 'Full Fact',
#    'country': 'United Kingdom',
#    'language': 'English',
#    'website': 'https://fullfact.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/full-fact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/full-fact_logo.png?v=1674591619',
#    'domain': 'fullfact.org'},
#   'appearances': ['https://www.facebook.com/photo.php?fbid=10165137980120517&set=a.10151037747100517&theater=&type=3'],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'We know that foods high in acid can break lateral flow tests and cause it to appear “positive”. However, research has shown that they very rarely deliver a false positive result when used properly, on people.',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'We know that foods high in acid can break lateral flow tests and cause it to appear “positive”. However, research has shown that they very rarely deliver a false positive result when used properly, on people.',
#      'ratingValue': None,
#      'bestRating': None,
#      'worstRating': None},
#     'retrieved_by': None,
#     'date_published': '2021-06-29'}]},
#  {'claim_text': ['Says the United States has “doubled our use of renewable energy.”'],
#   'label': 'not_credible',
#   'review_url': 'http://www.factcheck.org/2012/09/renewable-energy-doubled-not-quite/',
#   'fact_checker': {'name': 'FactCheck.org',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://factcheck.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/factcheckorg',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/factcheckorg_logo.png?v=1529432527',
#    'domain': 'factcheck.org'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '7',
#      'alternateName': 'False',
#      'worstRating': '1',
#      'bestRating': '11',
#      'image': 'https://s3.amazonaws.com/share-the-facts/rating_images/factcheck.org/false.png'},
#     'retrieved_by': None,
#     'date_published': '2016-06-10'}]},
#  {'claim_text': ['A retirada das redes desse pessoal já está sendo acertada com o Supremo e o TSE'],
#   'label': 'not_credible',
#   'review_url': 'https://noticias.uol.com.br/confere/ultimas-noticias/2022/11/14/e-falso-que-randolfe-assumiu-atuar-contra-politicos-de-direita-no-whatsapp.htm',
#   'fact_checker': {'name': 'UOL Confere',
#    'country': 'Brazil',
#    'language': 'Portuguese',
#    'website': 'https://noticias.uol.com.br/confere/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/uol-confere',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/uol-confere_logo.png?v=1644267903',
#    'domain': 'uol.com.br'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '6',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2022-11-14'}]},
#  {'claim_text': ['ছবির দাবি আমার প্রিয় নবীর দেশ মদিনা শরীফের একটি রাস্তা'],
#   'label': 'not_credible',
#   'review_url': 'https://bangla.boomlive.in/fact-check/road-of-seppeltsfield-australia-falsely-shared-as-medina-saudi-arabia-16659',
#   'fact_checker': {'name': 'BOOM',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.boomlive.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/boom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/boom_logo.png?v=1674590009',
#    'domain': 'boomlive.in'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '',
#      'ratingExplanation': 5,
#      'image': 'https://bangla.boomlive.in/h-upload/2022/02/07/969336-seppeltsfield-road-shared-falsely-as-medina-road-saudi-arabia-01.jpg',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2022-02-07'}]},
#  {'claim_text': ['Rahul Gandhi Continued Speaking When Mic Was Off'],
#   'label': 'not_verifiable',
#   'review_url': 'https://newschecker.in/fact-check/rahul-gandhi-mic-was-off-missing-context/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://twitter.com/rishibagree/status/1597472644970221568'],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Missing Context',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Missing Context',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2022-12-01'}]},
#  {'claim_text': ['Wombats are herding animals and inviting them into their burrows in order to escape the wildfires in Australia.'],
#   'label': 'uncertain',
#   'review_url': 'https://www.snopes.com/fact-check/hero-wombats-australia-fires/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'uncertain',
#     'original_label': 'Mixture',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'Mixture'},
#     'retrieved_by': None,
#     'date_published': '2020-01-16'}]},
#  {'claim_text': ['"São várias as imagens que mostram a existência de peixes e até golfinhos nos cais de Veneza..."'],
#   'label': 'not_credible',
#   'review_url': 'https://observador.pt/factchecks/fact-check-a-quarentena-deixou-as-aguas-de-veneza-mais-limpas-ao-ponto-de-aparecer-um-golfinho/',
#   'fact_checker': {'name': 'Observador - Fact Check',
#    'country': 'Portugal',
#    'language': 'Portuguese',
#    'website': 'https://www.observador.pt',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/observador-fact-check',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/observador-fact-check_logo.png?v=1643129328',
#    'domain': 'observador.pt'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Errado',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': 1,
#      'bestRating': 6,
#      'worstRating': 1,
#      'alternateName': 'Errado',
#      'image': 'https://bordalo.observador.pt/v2/rs:fill:770:403/c:500:275:nowe:0:0/q:86/plain/https://s3.observador.pt/wp-content/uploads/2020/01/09142359/fact_check-errado1x1.png'},
#     'retrieved_by': None,
#     'date_published': '2020-03-21'}]},
#  {'claim_text': ['Taliban have more Blackhawks than 166 other nations'],
#   'label': 'uncertain',
#   'review_url': 'https://leadstories.com/hoax-alert/2021/08/fact-check-taliban-does-have-more-black-hawk-helicopters-than-166-nations.html',
#   'fact_checker': {'name': 'Lead Stories',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://leadstories.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/lead-stories',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/lead-stories_logo.png?v=1534253991',
#    'domain': 'leadstories.com'},
#   'appearances': [],
#   'reviews': [{'label': 'uncertain',
#     'original_label': 'Not In Service',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '3',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Not In Service'},
#     'retrieved_by': None,
#     'date_published': '2021-08-20'}]},
#  {'claim_text': ['Der Vulkan auf La Palma blase im Moment soviel CO2 in die Luft, wie Deutschland in den nächsten 100 Jahren sparen wolle.'],
#   'label': 'not_credible',
#   'review_url': 'https://correctiv.org/faktencheck/2021/10/21/vulkanausbrueche-wie-der-auf-la-palma-produzieren-nur-einen-bruchteil-der-co2-emissionen-deutschlands/',
#   'fact_checker': {'name': 'CORRECTIV',
#    'country': 'Germany',
#    'language': 'German',
#    'website': 'http://correctiv.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/correctiv',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/correctiv_logo.png?v=1673543124',
#    'domain': 'correctiv.org'},
#   'appearances': ['https://www.facebook.com/www.debeste.de/photos/a.1450518735167600/3075976959288428',
#    'https://www.facebook.com/IchMussNichtZumLachenInDenKeller/photos/a.1413035658969482/3025902351016130'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falsch. Generell verursachen Vulkanausbrüche laut Experten nur einen Bruchteil dessen, was Deutschland in den nächsten Jahren an Treibhausgas-Emissionen sparen will. Wie viel CO2 der Vulkan auf La Palma aktuell ausstößt, lässt sich noch nicht sagen.',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Falsch. Generell verursachen Vulkanausbrüche laut Experten nur einen Bruchteil dessen, was Deutschland in den nächsten Jahren an Treibhausgas-Emissionen sparen will. Wie viel CO2 der Vulkan auf La Palma aktuell ausstößt, lässt sich noch nicht sagen.',
#      'bestRating': '8',
#      'worstRating': '0',
#      'ratingValue': '1'},
#     'retrieved_by': None,
#     'date_published': '2021-10-21'}]},
#  {'claim_text': ['Keto Diet Pills were backed by the judges from Shark Tank'],
#   'label': 'not_credible',
#   'review_url': 'https://leadstories.com/hoax-alert/2021/04/fact-check-shark-tank-judges-did-not-back-keto-pill.html',
#   'fact_checker': {'name': 'Lead Stories',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://leadstories.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/lead-stories',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/lead-stories_logo.png?v=1534253991',
#    'domain': 'leadstories.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False Promo',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False Promo'},
#     'retrieved_by': None,
#     'date_published': '2021-04-15'}]},
#  {'claim_text': ['It was not physically possible for a single gunman at the Orlando nightclub shooting to have fired as many rounds in the time allotted as reported.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.snopes.com/fact-check/orlando-mass-shooting-math-doesnt-add-up/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2016-06-15'}]},
#  {'claim_text': ['Agua tibia o caliente con limón cura o alivia el cáncer.'],
#   'label': 'not_credible',
#   'review_url': 'https://factual.afp.com/beber-agua-caliente-sola-o-con-limon-no-cura-el-cancer',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://twitter.com/ingridcoronado/status/195272259324219392'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2019-12-04'}]},
#  {'claim_text': ['मुस्लिम युवक द्वारा मंदिर के पुजारी को बेरहमी से पीटा गया.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.altnews.in/hindi/old-video-of-fatehpur-hariyana-of-a-priest-beaten-up-shared-with-false-communal-angle/',
#   'fact_checker': {'name': 'Pravda Media Foundation',
#    'country': 'India',
#    'language': 'English',
#    'website': 'https://www.altnews.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/pravda-media-foundation',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/pravda-media-foundation_logo.png?v=1549920914',
#    'domain': 'altnews.in'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2023-03-03'}]},
#  {'claim_text': ['کیرلہ کی غیر مسلم لڑکی نے مسلمان لڑکے سے شادی کی۔اس کے بعد لڑکے نے لڑکی کو مارا پیٹا۔'],
#   'label': 'not_credible',
#   'review_url': 'https://newschecker.in/ur/fact-check-ur/a-picture-of-muslim-bangladeshi-couple-is-shared-on-social-media-linked-with-love-jihad/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://m.facebook.com/groups/1062689177481657?view=permalink&id=1069955810088327&sfnsn=wiwspwa&extid=mojfMO8Xmlj1sRD1'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'False',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2020-09-25'}]},
#  {'claim_text': ['Vídeo mostra protesto de caminhoneiros contra passaporte sanitário no Canadá'],
#   'label': 'not_credible',
#   'review_url': 'https://www.aosfatos.org/noticias/video-mostra-protesto-agricultores-alemanha-nao-antivacina-canada/',
#   'fact_checker': {'name': 'Aos Fatos',
#    'country': 'Brazil',
#    'language': 'Portuguese',
#    'website': 'https://aosfatos.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/aos-fatos',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/aos-fatos_logo.png?v=1583784059',
#    'domain': 'aosfatos.org'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': 1,
#      'bestRating': 6,
#      'alternateName': 'falso',
#      'image': 'https://aosfatos.org/static/images/aosfatos.png'},
#     'retrieved_by': None,
#     'date_published': '2022-01-31'}]},
#  {'claim_text': ["U.S. Rep. Louie Gohmert asked whether the moon's orbit could be changed to help solve the issue of climate change."],
#   'label': 'credible',
#   'review_url': 'https://www.snopes.com/fact-check/gohmert-moon-climate-change/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'credible',
#     'original_label': 'Correct Attribution',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Correct Attribution'},
#     'retrieved_by': None,
#     'date_published': '2021-06-10'}]},
#  {'claim_text': ['Photo shows dogs sitting on hospital beds in India in 2020'],
#   'label': 'not_credible',
#   'review_url': 'https://factcheck.afp.com/photo-has-circulated-online-least-2017-reports-about-stray-dogs-india',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://twitter.com/DFFzw4It2S7i9gI/status/1288369290966495232'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '2.5',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Misleading'},
#     'retrieved_by': None,
#     'date_published': '2020-08-05'}]},
#  {'claim_text': ['Roman Abramovich, "recém-português", participou nas negociações entre Moscovo e Kiev?'],
#   'label': 'credible',
#   'review_url': 'https://poligrafo.sapo.pt/fact-check/roman-abramovich-recem-portugues-participou-nas-negociacoes-entre-moscovo-e-kiev',
#   'fact_checker': {'name': 'Polígrafo',
#    'country': 'Portugal',
#    'language': 'Portuguese',
#    'website': 'https://poligrafo.sapo.pt',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/poligrafo',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/poligrafo_logo.png?v=1644521915',
#    'domain': 'sapo.pt'},
#   'appearances': [],
#   'reviews': [{'label': 'credible',
#     'original_label': 'Verdadeiro',
#     'review_rating': {'ratingValue': '5',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Verdadeiro',
#      '@type': 'Rating'},
#     'retrieved_by': None,
#     'date_published': '2022-03-02'}]},
#  {'claim_text': ['ਫੋਟੋ ਵਿੱਚ ਦਿੱਖ ਰਹੇ ਤਿਰੰਗਾ ਫੜੇ ਹੋਏ ਵਿਦਿਆਰਥੀ ਪਾਕਿਸਤਾਨ ਦੇ ਹਨ'],
#   'label': 'not_credible',
#   'review_url': 'https://www.vishvasnews.com/punjabi/world/fact-check-photo-of-students-coming-from-ukraine-holding-the-tricolor-is-of-indian-students-not-of-pakistanis/',
#   'fact_checker': {'name': 'MMI Online Limited',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.vishvasnews.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/mmi-online-limited',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/mmi-online-limited_logo.png?v=1548049223',
#    'domain': 'vishvasnews.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2022-03-08'}]},
#  {'claim_text': ["Atal Bihari Vajpayee's Niece Criticising Government"],
#   'label': 'not_credible',
#   'review_url': 'https://www.thequint.com/news/webqoof/no-thats-not-vajpayees-niece-slamming-the-govt-in-viral-video',
#   'fact_checker': {'name': 'The Quint',
#    'country': 'India',
#    'language': 'English',
#    'website': 'https://www.thequint.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/the-quint',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/the-quint_logo.png?v=1533993138',
#    'domain': 'thequint.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '0',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2020-10-07'}]},
#  {'claim_text': ['Claims that Christian apologist C.S. Lewis once said, "You can\'t go back and change the beginning, but you can start where you are and change the ending."'],
#   'label': 'not_credible',
#   'review_url': 'http://checkyourfact.com/2019/07/26/fact-check-cs-lewis-cant-go-back-change-beginning-start-ending/',
#   'fact_checker': {'name': 'Check Your Fact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://checkyourfact.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/check-your-fact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/check-your-fact_logo.png?v=1674592972',
#    'domain': 'checkyourfact.com'},
#   'appearances': ['https://www.facebook.com/astepaheadchattanooga/posts/2426804454043333'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '3',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2019-07-26'}]},
#  {'claim_text': ['Photograph shows recent Kisan Mahapanchayat in Muzaffarnagar.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.thequint.com/news/webqoof/shamli-photo-of-farmers-protest-shared-as-recent-mahapanchayat-fact-check',
#   'fact_checker': {'name': 'The Quint',
#    'country': 'India',
#    'language': 'English',
#    'website': 'https://www.thequint.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/the-quint',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/the-quint_logo.png?v=1533993138',
#    'domain': 'thequint.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '2',
#      'bestRating': '5',
#      'worstRating': '0',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2021-09-06'}]},
#  {'claim_text': ['Eat yoghurt, lime and honey every day to treat gallstones'],
#   'label': 'uncertain',
#   'review_url': 'https://factcheck.afp.com/doc.afp.com.32DH8BY',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/witeethammachad/posts/2034973556705829'],
#   'reviews': [{'label': 'uncertain',
#     'original_label': 'Missing Context',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '3',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Missing Context'},
#     'retrieved_by': None,
#     'date_published': '2022-07-05'}]},
#  {'claim_text': ['وائرل تصویر بہار کے سیمانچل کی ہے۔اس تصویر کو انگلش ہندی کیپشن کے ساتھ شیئر کیا گیا ہے۔'],
#   'label': 'not_credible',
#   'review_url': 'https://newschecker.in/ur/fact-check-ur/viral-ur/bangladesh-flood-affected-area-picture-is-shared-in-the-name-of-bihar-seemanchal-on-social/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://www.facebook.com/photo.php?fbid=2650276988624765&set=gm.602820953682204&type=1&theater'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Misleading',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2020-07-14'}]},
#  {'claim_text': ['Japanese train running at 4800km/hr'],
#   'label': 'not_credible',
#   'review_url': 'https://newschecker.in/fact-check/heres-the-truth-behind-the-viral-video-that-claims-to-show-japanese-train-travelling-at-4800-km-hr/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://twitter.com/yvs_raizada/status/1578712114692526081'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'False',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2022-10-17'}]},
#  {'claim_text': ["Hong Kong Chief Executive Carrie Lam was not given the COVID-19 vaccine made by China's Sinovac but instead, given a vaccine in a prefilled syringe manufactured by a European pharmaceutical company."],
#   'label': 'not_credible',
#   'review_url': 'https://annielab.org/2021/02/28/analysis-questions-about-carrie-lams-jab-syringe-was-filled-from-a-sinovac-vial/',
#   'fact_checker': {'name': 'Annie Lab',
#    'country': 'Hong Kong',
#    'language': 'English',
#    'website': 'http://annielab.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/annie-lab',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/annie-lab_logo.png?v=1643281677',
#    'domain': 'annielab.org'},
#   'appearances': ['https://lihkg.com/thread/2417934/page/1',
#    'https://www.facebook.com/germanyswhk/posts/471375287570427',
#    'https://www.facebook.com/AndrewWanbulletin/posts/5372092429467432',
#    'https://twitter.com/aHongKonggirl1/status/1363770929055031298'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False. Photos and videos from the local news media clearly show the syringe used to inoculate Chief Executive Carrie Lam was filled from a Sinovac vial.',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'False. Photos and videos from the local news media clearly show the syringe used to inoculate Chief Executive Carrie Lam was filled from a Sinovac vial.',
#      'bestRating': '',
#      'worstRating': '',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2021-02-28'}]},
#  {'claim_text': ['In January 2022, U.S. military officials executed former President George W. Bush at Guantanamo Bay.'],
#   'label': 'not_verifiable',
#   'review_url': 'https://www.snopes.com/fact-check/george-w-bush-guantanamo-bay/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Originated as Satire',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Originated as Satire'},
#     'retrieved_by': None,
#     'date_published': '2022-01-22'}]},
#  {'claim_text': ['شاہ رخ خان کی آئندہ فلم ’ٹیپو سلطان‘‘ کا اس طرح بائیکاٹ ہونا چاہئے کہ یہ اس کے کرئیر کی آخری فلم ہو'],
#   'label': 'not_credible',
#   'review_url': 'https://www.vishvasnews.com/urdu/viral/fact-check-shahrukh-khan-is-not-making-a-movie-on-tipu-sultan-viral-movie-poster-is-fake/',
#   'fact_checker': {'name': 'MMI Online Limited',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.vishvasnews.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/mmi-online-limited',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/mmi-online-limited_logo.png?v=1548049223',
#    'domain': 'vishvasnews.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2020-05-08'}]},
#  {'claim_text': ['Uganda only has 19 deaths related to the coronavirus because hydroxychloroquine "is eaten like candy" in the country.'],
#   'label': 'not_credible',
#   'review_url': 'http://checkyourfact.com/2020/10/02/fact-check-uganda-coronavirus-deaths-hydroxychloroquine-lockdown/',
#   'fact_checker': {'name': 'Check Your Fact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://checkyourfact.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/check-your-fact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/check-your-fact_logo.png?v=1674592972',
#    'domain': 'checkyourfact.com'},
#   'appearances': ['https://www.facebook.com/photo.php?fbid=1210387666014915&set=a.198404633879895&theater=&type=3'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '3',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2020-10-02'}]},
#  {'claim_text': ['Microwaved foods lead to a higher percentage of cancerous cells in the bloodstream.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.aap.com.au/factcheck/microwave-meme-cooks-up-cancer-food-fears/',
#   'fact_checker': {'name': 'Australian Associated Press',
#    'country': 'Australia',
#    'language': 'English',
#    'website': 'https://www.aap.com.au/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/australian-associated-press',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/australian-associated-press_logo.png?v=1557103840',
#    'domain': 'aap.com.au'},
#   'appearances': ['https://www.facebook.com/wesaynoto5ginaustralia/photos/a.1139242102907883/2287066084792140/?type=3'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False. There is no evidence that microwaved foods cause cancer or increase cancerous cells.',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'False. There is no evidence that microwaved foods cause cancer or increase cancerous cells.',
#      'bestRating': '',
#      'worstRating': '',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2022-08-31'}]},
#  {'claim_text': ['George Soros doou US$ 300 milhões para campanha de Alckmin'],
#   'label': 'not_credible',
#   'review_url': 'https://noticias.uol.com.br/confere/ultimas-noticias/2018/08/04/george-soros-nao-doou-us-300-milhoes-para-campanha-de-alckmin.htm',
#   'fact_checker': {'name': 'UOL Confere',
#    'country': 'Brazil',
#    'language': 'Portuguese',
#    'website': 'https://noticias.uol.com.br/confere/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/uol-confere',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/uol-confere_logo.png?v=1644267903',
#    'domain': 'uol.com.br'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2018-08-04'}]},
#  {'claim_text': ['Claims to show an advertisement arguing that very young children should drink soda.'],
#   'label': 'not_credible',
#   'review_url': 'http://checkyourfact.com/2022/06/23/fact-check-soda-pop-infants-advertisement/',
#   'fact_checker': {'name': 'Check Your Fact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://checkyourfact.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/check-your-fact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/check-your-fact_logo.png?v=1674592972',
#    'domain': 'checkyourfact.com'},
#   'appearances': ['https://www.facebook.com/david.kurz/posts/pfbid02WxHFoLgjPmRpphGUnqmvWQkuBCSeH5we9B6yJByHfzGAoxnPMCHqW317S9FJG9fcl'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '3',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2022-06-23'}]},
#  {'claim_text': ['आंध्र प्रदेश के गुंटुर में मुस्लिमों ने मंदिर को तोड़ा है।'],
#   'label': 'not_credible',
#   'review_url': 'https://www.vishvasnews.com/viral/fact-check-guntur-dargah-demolition-attempt-viral-with-false-link-to-temple/',
#   'fact_checker': {'name': 'MMI Online Limited',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.vishvasnews.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/mmi-online-limited',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/mmi-online-limited_logo.png?v=1548049223',
#    'domain': 'vishvasnews.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2022-10-19'}]},
#  {'claim_text': ['On the night of March 16, 2021, former U.S. President Donald Trump called in to Fox News and referred to the coronavirus as the &quot;China virus&quot; in an interview.'],
#   'label': 'credible',
#   'review_url': 'https://www.snopes.com/fact-check/trump-china-virus-atlanta-shooting/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'credible',
#     'original_label': 'True',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'True'},
#     'retrieved_by': None,
#     'date_published': '2021-03-17'}]},
#  {'claim_text': ["Video shows Dalit man drinking urine from an upper caste person's shoe."],
#   'label': 'not_credible',
#   'review_url': 'https://www.boomlive.in/fact-check/old-video-dalit-man-drinking-urine-from-caste-man-shoe-rajasthan-old-video-fact-check-21593',
#   'fact_checker': {'name': 'BOOM',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.boomlive.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/boom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/boom_logo.png?v=1674590009',
#    'domain': 'boomlive.in'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '',
#      'ratingExplanation': 5,
#      'image': 'https://www.boomlive.in/h-upload/2023/04/07/1002659-dalit-person-01.jpg',
#      'alternateName': 'Misleading'},
#     'retrieved_by': None,
#     'date_published': '2023-04-07'}]},
#  {'claim_text': ['TAP apresentou prejuízos em nove dos últimos dez anos?'],
#   'label': 'credible',
#   'review_url': 'https://poligrafo.sapo.pt/fact-check/tap-apresentou-prejuizos-em-nove-dos-ultimos-dez-anos',
#   'fact_checker': {'name': 'Polígrafo',
#    'country': 'Portugal',
#    'language': 'Portuguese',
#    'website': 'https://poligrafo.sapo.pt',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/poligrafo',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/poligrafo_logo.png?v=1644521915',
#    'domain': 'sapo.pt'},
#   'appearances': [],
#   'reviews': [{'label': 'credible',
#     'original_label': 'Verdadeiro',
#     'review_rating': {'ratingValue': '5',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Verdadeiro',
#      '@type': 'Rating'},
#     'retrieved_by': None,
#     'date_published': '2020-12-12'}]},
#  {'claim_text': ['Najpierw była konwencja z Kioto, która zobowiązywała nas do ośmioprocentowego ograniczenia [emisji gazów cieplarnianych] – myśmy ograniczyli emisję o 30 procent.'],
#   'label': 'not_verifiable',
#   'review_url': 'https://demagog.org.pl/wypowiedzi/o-ile-polska-ograniczyla-emisje-gazow-cieplarnianych/',
#   'fact_checker': {'name': 'Demagog Association',
#    'country': 'Poland',
#    'language': 'Polish',
#    'website': 'https://demagog.org.pl',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/demagog-association',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/demagog-association_logo.png?v=1558109503',
#    'domain': 'demagog.org.pl'},
#   'appearances': ['https://www.prezydent.pl/aktualnosci/wypowiedzi-prezydenta-rp/wystapienia/art',
#    'https://www.prezydent.pl/aktualnosci/wypowiedzi-prezydenta-rp/wystapienia/art,968,wystapienie-podczas-spotkania-z-mieszkancami-lubartowa.html'],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Manipulacja',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'Manipulacja'},
#     'retrieved_by': None,
#     'date_published': '2020-02-19'}]},
#  {'claim_text': ['വാടക ഇനത്തില്\u200d കോടികള്\u200d വെട്ടിക്കാനായാണ് ബ്രഹ്\u200cമപുരം മാലിന്യ പ്ലാന്റിലെ തീ അണയ്ക്കാന്\u200d സര്\u200dക്കാര്\u200d, ഹെലികോപ്റ്റര്\u200d ഉപയോഗിക്കുന്നത്'],
# ...
#   'label': 'not_credible',
#   'review_url': 'http://www.politifact.com/article/2018/mar/24/fact-checking-march-our-lives/',
#   'fact_checker': {'name': 'PolitiFact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://www.politifact.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/politifact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/politifact_logo.png?v=1528378650',
#    'domain': 'politifact.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Pants on Fire',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'alternateName': 'Pants on Fire',
#      'worstRating': '1',
#      'bestRating': '7',
#      'image': 'https://dhpikd1t89arn.cloudfront.net/rating_images/politifact/tom-pof.png'},
#     'retrieved_by': None,
#     'date_published': '2018-03-23'}]},
#  {'claim_text': ['W\xa0roku 1997 większość parlamentarna [przyp.red] stanowiona przez\xa0Sojusz Lewicy Demokratycznej i\xa0jego koalicjanta mogła, nie zmieniając żadnych ustaw, także w\xa0wyniku wejścia w\xa0życie nowej Konstytucji, wybrać sobie sędziów do\xa0Trybunału Konstytucyjnego i\xa0uzyskać w\xa0tym Trybunale zdecydowaną przewagę. (…) SLD nie zdecydowało się na\xa0ten wybór. Następny Sejm dokonał wyboru nowych sędziów.'],
#   'label': 'not_verifiable',
#   'review_url': 'https://demagog.org.pl/wypowiedzi/zmiana-sedziow-trybunalu-konstytucyjnego/',
#   'fact_checker': {'name': 'Demagog Association',
#    'country': 'Poland',
#    'language': 'Polish',
#    'website': 'https://demagog.org.pl',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/demagog-association',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/demagog-association_logo.png?v=1558109503',
#    'domain': 'demagog.org.pl'},
#   'appearances': ['http://isap.sejm.gov.pl/DetailsServlet?id=WDU19911090470'],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Fałsz.',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'Fałsz.'},
#     'retrieved_by': None,
#     'date_published': '2015-12-23'}]},
#  {'claim_text': ['অভিজিৎ বন্দোপাধ্যায় বলেছেন—আমি ভারতের নতুন কৃষি আইন পড়ে দেখেছি। বুঝেছি, তা ত্রুটিপূর্ণ এবং কৃষকদের পক্ষে ক্ষতিকারক'],
#   'label': 'not_credible',
#   'review_url': 'https://bangla.boomlive.in/fake-news/farmers-protest-economist-kaushik-basus-quote-in-newspaper-clipping-viral-as-abhijeet-banerjee-11151',
#   'fact_checker': {'name': 'BOOM',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.boomlive.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/boom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/boom_logo.png?v=1674590009',
#    'domain': 'boomlive.in'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '',
#      'ratingExplanation': 5,
#      'image': 'https://bangla.boomlive.in/h-upload/2020/12/15/936371-kausik-basus-remarks-on-farm-bill-shared-as-abhijeet-banerjees-comment-01.jpg',
#      'alternateName': 'Misleading'},
#     'retrieved_by': None,
#     'date_published': '2020-12-15'}]},
#  {'claim_text': ['The presidential practice of pardoning a live turkey before Thanksgiving originated with President Harry Truman in 1947.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.snopes.com/fact-check/the-ungobbled-gobbler/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2007-11-14'}]},
#  {'claim_text': ['राजस्\u200dथान के मुख्\u200dयमंत्री अशोक गहलोत ने अमृतपाल सिंह की खालिस्\u200dतान मांगने वाली बात का समर्थन किया है।'],
#   'label': 'not_credible',
#   'review_url': 'https://www.vishvasnews.com/politics/fact-check-rajasthan-cm-ashok-gehlot-statement-over-amritpal-singh-viral-with-misleading-claim/',
#   'fact_checker': {'name': 'MMI Online Limited',
#    'country': 'India',
#    'language': 'English',
#    'website': 'http://www.vishvasnews.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/mmi-online-limited',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/mmi-online-limited_logo.png?v=1548049223',
#    'domain': 'vishvasnews.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2023-04-11'}]},
#  {'claim_text': ['फेक है Instagram का BoisLockerRoom मामला'],
#   'label': 'not_credible',
#   'review_url': 'https://newschecker.in/hi/fact-check-hi/is-instagrams-bois-locker-room-case-fake/',
#   'fact_checker': {'name': 'Newschecker',
#    'country': 'India',
#    'language': 'Hindi',
#    'website': 'http://www.newschecker.in',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/newschecker',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/newschecker_logo.png?v=1683189293',
#    'domain': 'newschecker.in'},
#   'appearances': ['https://twitter.com/pritsi2101/status/1259684986841640960?ref_src=twsrc%5Etfw%7Ctwcamp%5Etweetembed%7Ctwterm%5E1259684986841640960%7Ctwgr%5E3d86ca92b56ce0fb5090c0b99ba98ebc0337dfb9%7Ctwcon%5Es1_c10#038;ref_url=https://newschecker.in/wp-admin/post.php?post=15885563action=editlang=hi'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Misleading',
#     'review_rating': {'@type': 'Rating',
#      'alternateName': 'Misleading',
#      'bestRating': '2',
#      'worstRating': '2',
#      'ratingValue': ''},
#     'retrieved_by': None,
#     'date_published': '2020-05-11'}]},
#  {'claim_text': ['Diamante com 2 toneladas e meia que já estava em uma ONG se preparando para viajar .Exército invadiu apreendeu esse tesouro agora. Isso a Globolixo não mostra. Isso agora pertence ao Brasil, isso Você que torce para que o Brasil dê certo, o mínimo que você pode fazer é repassar esse texto e o vídeo em anexo para todos os seus contatos.'],
#   'label': 'not_credible',
#   'review_url': 'https://www.aosfatos.org/noticias/ong-nao-foi-flagrada-pelo-exercito-com-diamante-de-mais-de-duas-toneladas-na-amazonia/',
#   'fact_checker': {'name': 'Aos Fatos',
#    'country': 'Brazil',
#    'language': 'Portuguese',
#    'website': 'https://aosfatos.org',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/aos-fatos',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/aos-fatos_logo.png?v=1583784059',
#    'domain': 'aosfatos.org'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': 1,
#      'bestRating': 6,
#      'alternateName': 'falso',
#      'image': 'https://aosfatos.org/static/images/aosfatos.png'},
#     'retrieved_by': None,
#     'date_published': '2019-09-12'}]},
#  {'claim_text': ['Barack Obama urged his supporters to join him in changing &quot;the greatest nation in the history of the world.&quot;'],
#   'label': 'not_credible',
#   'review_url': 'https://www.snopes.com/fact-check/small-change/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2008-03-14'}]},
#  {'claim_text': ["Scène de torture par l'armée camerounaise en zone anglophone"],
#   'label': 'not_credible',
#   'review_url': 'https://factuel.afp.com/non-cette-photo-na-pas-ete-prise-au-cameroun',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/CamerNation/photos/a.1138437942937031/1454723271308495?theater=&type=3'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Faux, cette photo n’a pas été prise au Cameroun',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '1',
#      'worstRating': '5',
#      'alternateName': 'Faux, cette photo n’a pas été prise au Cameroun'},
#     'retrieved_by': None,
#     'date_published': '2019-12-02'}]},
#  {'claim_text': ['Haddad disse que desvio de dinheiro é natural no serviço público'],
#   'label': 'not_credible',
#   'review_url': 'https://noticias.uol.com.br/comprova/ultimas-noticias/2018/09/20/fala-de-cid-gomes-e-tirada-de-contexto-e-atribuida-a-haddad.htm',
#   'fact_checker': {'name': 'UOL Confere',
#    'country': 'Brazil',
#    'language': 'Portuguese',
#    'website': 'https://noticias.uol.com.br/confere/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/uol-confere',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/uol-confere_logo.png?v=1644267903',
#    'domain': 'uol.com.br'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Falso',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '4',
#      'worstRating': '1',
#      'alternateName': 'Falso'},
#     'retrieved_by': None,
#     'date_published': '2018-09-20'}]},
#  {'claim_text': ["Un uomo che aveva preso in ostaggio un'anziana è stato ucciso dalla polizia brasiliana"],
#   'label': 'not_verifiable',
#   'review_url': 'https://facta.news/notizia-vera/2020/07/10/il-video-delluomo-ucciso-dopo-aver-preso-unanziana-in-ostaggio-e-reale-ed-e-stato-girato-in-brasile/',
#   'fact_checker': {'name': 'Facta',
#    'country': 'Italy',
#    'language': 'English',
#    'website': 'https://facta.news/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/facta',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/facta_logo.png?v=1615286765',
#    'domain': 'facta.news'},
#   'appearances': [],
#   'reviews': [{'label': 'not_verifiable',
#     'original_label': 'Notizia vera',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'Notizia vera'},
#     'retrieved_by': None,
#     'date_published': '2020-07-10'}]},
#  {'claim_text': ['Singa meronda jalan di Rusia semasa perintah berkurung koronavirus'],
#   'label': 'not_credible',
#   'review_url': 'https://semakanfakta.afp.com/foto-singa-ini-diambil-di-afrika-selatan-pada-2016-ia-tidak-berkaitan-dengan-pandemik-koronavirus',
#   'fact_checker': {'name': 'AFP fact checking',
#    'country': 'France',
#    'language': 'French',
#    'website': 'https://www.afp.com/en',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/afp-fact-checking',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/afp-fact-checking_logo.png?v=1612201098',
#    'domain': 'afp.com'},
#   'appearances': ['https://www.facebook.com/wartakerisselatklang/photos/a.1754737151267494/3606886876052503?theater=&type=3'],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Tak Benar',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '1',
#      'alternateName': 'Tak Benar'},
#     'retrieved_by': None,
#     'date_published': '2020-04-07'}]},
#  {'claim_text': ['"This type of mass violence does not happen in other advanced countries ... with this kind of frequency."'],
#   'label': 'not_credible',
#   'review_url': 'http://www.politifact.com/factchecks/2015/jun/22/barack-obama/barack-obama-correct-mass-killings-dont-happen-oth/',
#   'fact_checker': {'name': 'PolitiFact',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'http://www.politifact.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/politifact',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/politifact_logo.png?v=1528378650',
#    'domain': 'politifact.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Mostly False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '3',
#      'alternateName': 'Mostly False',
#      'worstRating': '1',
#      'bestRating': '7',
#      'image': 'https://dhpikd1t89arn.cloudfront.net/rating_images/politifact/tom-mostlyfalse.jpg'},
#     'retrieved_by': None,
#     'date_published': '2016-04-18'}]},
#  {'claim_text': ['"Congresso do Chile aprova novo projeto que substituirá a palavra \'mulher\' por \'pessoa menstruante\'. Onde está o meteoro?"'],
#   'label': 'not_credible',
#   'review_url': 'https://observador.pt/factchecks/fact-check-congresso-chileno-aprovou-lei-para-substituir-a-palavra-mulher-por-pessoa-menstruante/',
#   'fact_checker': {'name': 'Observador - Fact Check',
#    'country': 'Portugal',
#    'language': 'Portuguese',
#    'website': 'https://www.observador.pt',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/observador-fact-check',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/observador-fact-check_logo.png?v=1643129328',
#    'domain': 'observador.pt'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'Enganador',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': 2,
#      'bestRating': 6,
#      'worstRating': 1,
#      'alternateName': 'Enganador',
#      'image': 'https://bordalo.observador.pt/v2/rs:fill:770:403/c:500:275:nowe:0:0/q:86/plain/https://s3.observador.pt/wp-content/uploads/2020/01/09142612/fact_check-enganador1x1.png'},
#     'retrieved_by': None,
#     'date_published': '2022-05-24'}]},
#  {'claim_text': ["The video shows cracks in the Earth's surface that were caused due to earthquakes in Turkey and Syria."],
#   'label': 'not_credible',
#   'review_url': 'https://www.thequint.com/news/webqoof/video-of-huge-crack-in-china-shared-as-turkey-earthquake-fact-check',
#   'fact_checker': {'name': 'The Quint',
#    'country': 'India',
#    'language': 'English',
#    'website': 'https://www.thequint.com/',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/the-quint',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/the-quint_logo.png?v=1533993138',
#    'domain': 'thequint.com'},
#   'appearances': [],
#   'reviews': [{'label': 'not_credible',
#     'original_label': 'False',
#     'review_rating': {'@type': 'Rating',
#      'ratingValue': '1',
#      'bestRating': '5',
#      'worstRating': '0',
#      'alternateName': 'False'},
#     'retrieved_by': None,
#     'date_published': '2023-02-22'}]},
#  {'claim_text': ['Clueless cooks in the process of committing Thanksgiving mayhem call turkey hotlines.'],
#   'label': 'credible',
#   'review_url': 'https://www.snopes.com/fact-check/lets-talk-turkey/',
#   'fact_checker': {'name': 'Snopes.com',
#    'country': 'United States',
#    'language': 'English',
#    'website': 'https://www.snopes.com',
#    'ifcn_url': 'https://ifcncodeofprinciples.poynter.org/profile/snopescom',
#    'avatar': 'https://ifcncodeofprinciples.poynter.org/storage/logos/snopescom_logo.png?v=1529435679',
#    'domain': 'snopes.com'},
#   'appearances': [],
#   'reviews': [{'label': 'credible',
#     'original_label': 'True',
#     'review_rating': {'@type': 'Rating', 'alternateName': 'True'},
#     'retrieved_by': None,
#     'date_published': '2005-11-20'}]},
#  ...]

# %%
claim_reviews_time_range = []

for cr in claim_reviews_full:
    d = cr['reviews'][0]['date_published']
    
    if d and datetime.strptime(d, '%Y-%m-%d') >start_date and datetime.strptime(d, '%Y-%m-%d') < end_date:
        claim_reviews_time_range.append(cr)


claim_reviews = claim_reviews_time_range
len(claim_reviews)
# Out:
# 43161

# %%
cr_en = []
for i in trange(0, len(claim_reviews)):
    text = claim_reviews[i]['claim_text'][0]
    try:
        code = Detector(text).language.code
        if code =='en':
            cr_en.append(claim_reviews[i])
    except:
        pass
claim_reviews = cr_en
# Out:
# 100%|██████████████████████████████████████| 43161/43161 [00:00<00:00, 56594.54it/s]

# %%
df = pd.read_csv(cr_path+'factors.csv')
emotions = df['emotions'].tolist()
biases = df['biases'].tolist()
sentiments = df['sentiments'].tolist()
cons = df['conspiracies'].tolist()
with open(cr_path+"entities.json", "r") as outfile:
    ents = json.load(outfile)
len(df), len(ents)
# Out:
# (17996, 17996)

# %%
d_factors_cr = {}
for i in trange(0, len(claim_reviews)):
    cr = claim_reviews[i]
    identifier_cr = 'claim-review'+cr['claim_text'][0]+cr['label']+cr['review_url']
    uri = prefix+uri_generator(identifier_cr)
    
    d_factors_cr[uri] = [ents[i], emotions[i], biases[i], sentiments[i], cons[i]]
# Out:
# 100%|█████████████████████████████████████| 17996/17996 [00:00<00:00, 216584.87it/s]

# %% [markdown]
# ### CR - Graph

# %%
g = Graph()

# %%
URL_AVAILABLE_CHARS = """ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789-._~:/?#[]@!$&'()*+,;="""

for i in trange(0, len(claim_reviews)):
    cr_doc = claim_reviews[i]
    
    identifier = 'claim-review'+cr_doc['claim_text'][0]+cr_doc['label']+cr_doc['review_url']
    uri = 'claim-review'+uri_generator(identifier)
    g.add((URIRef(prefix+uri), RDF.type, SCHEMA.ClaimReview))
    
    author = cr_doc['fact_checker']['name']
    website = cr_doc['fact_checker']['website']
    identifier_author = 'organization'+str(author)
    uri_author = 'organization/'+uri_generator(identifier_author)
    
    g.add((URIRef(prefix+uri_author), RDF.type, SCHEMA.Organization))
    g.add((URIRef(prefix+uri_author), SCHEMA.name, Literal(author)))
    g.add((URIRef(prefix+uri_author), SCHEMA.url, URIRef(website)))

    g.add((URIRef(prefix+uri), SCHEMA.author, URIRef(prefix+uri_author)))

    date = cr_doc['reviews'][0]['date_published']
    g.add((URIRef(prefix+uri), SCHEMA.datePublished, Literal(date, datatype=XSD.date)))
    
    url = cr_doc['review_url']
    url = url.replace(' ', '')
    g.add((URIRef(prefix+uri), SCHEMA.url, URIRef(url)))
    
    language = cr_doc['fact_checker']['language']
    g.add((URIRef(prefix+uri), SCHEMA.inLanguage, Literal(language)))
    
    uri_normalized_rating = 'rating/'+cr_doc['reviews'][0]['label']
    g.add((URIRef(prefix+uri), CIMPLE.normalizedReviewRating, URIRef(prefix+uri_normalized_rating)))
    
    uri_original_rating = 'rating/'+uri_generator('rating'+cr_doc['reviews'][0]['original_label'])
    g.add((URIRef(prefix+uri), SCHEMA.reviewRating, URIRef(prefix+uri_original_rating)))

    
    claim = cr_doc['claim_text'][0]
    identifier_claim = 'claim'+claim
    uri_claim = 'claim/'+uri_generator(identifier_claim)
    
    #SCHEMA.Claim has not yet been integrated
    #This term is proposed for full integration into Schema.org, pending implementation feedback and adoption from applications and websites. 
    g.add((URIRef(prefix+uri_claim),RDF.type, SCHEMA.Claim))
    
    g.add((URIRef(prefix+uri), SCHEMA.itemReviewed, URIRef(prefix+uri_claim)))

    text = claim
    text = normalize_text(text)
    g.add((URIRef(prefix+uri_claim),SCHEMA.text, Literal(text)))
    
    appearances = cr_doc['appearances']
    for a in appearances:
        if a != None:
#             identifier_appearance = 'appearance'+str(a)
#             uri_appearance = 'appearance/'+uri_generator(identifier_appearance)
#             g.add((URIRef(prefix+uri_appearance), RDF.type, SCHEMA.CreativeWork))
#             g.add((URIRef(prefix+uri_appearance), SCHEMA.url, URIRef(a)))
            b = ''.join([i for i in a if i in URL_AVAILABLE_CHARS])
            g.add((URIRef(prefix+uri_claim), SCHEMA.appearance, URIRef(b)))

    
    
    r = measure_readability(text)
    g.add((URIRef(prefix+uri_claim), CIMPLE.readability_score, Literal(r)))

    e = emotions[i]
    if e != 'None':
        g.add((URIRef(prefix+uri_claim), CIMPLE.hasEmotion, URIRef(prefix+'emotion/'+str(e.lower()))))
    s = sentiments[i]
    g.add((URIRef(prefix+uri_claim), CIMPLE.hasSentiment, URIRef(prefix+'sentiment/'+str(s.lower()))))
    b = biases[i]
    g.add((URIRef(prefix+uri_claim), CIMPLE.hasPoliticalLeaning, URIRef(prefix+'political-leaning/'+str(b.lower()))))
    cons_i = json.loads(cons[i])
    for k in range(0, len(cons_i)):
        if cons_i[k] == 1:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri_claim), CIMPLE.mentionsConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
        elif cons_i[k] == 2:
            c = CONSPIRACIES[k]
            g.add((URIRef(prefix+uri_claim), CIMPLE.promotesConspiracy, URIRef(prefix+'conspiracy/'+str(c.replace(' ', '_').lower()))))
    
    entities = ents[i]
    if 'Resources' in entities:
        for ent in entities['Resources']:
            dbpedia_url = ent['@URI']
#             uri_mention = 'entity/'+uri_generator(dbpedia_url)
#             dbpedia_name = dbpedia_url.split('/')[-1].replace('_', ' ')                
            
#             g.add((URIRef(prefix+uri_mention), RDF.type, SCHEMA.Thing))
#             e_types = e['@types'].split(',')
#             for t in e_types:
#                 if "Wikidata" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(WIKI_prefix+t.split(':')[1])))
#                 if "DBpedia" in t:
#                     g.add((URIRef(prefix+uri_mention), RDF.type, URIRef(DB_prefix+t.split(':')[1])))

#             g.add((URIRef(prefix+uri_mention), SCHEMA.url, URIRef(dbpedia_url)))
#             g.add((URIRef(prefix+uri_mention), SCHEMA.name, Literal(dbpedia_name)))

            g.add((URIRef(prefix+uri_claim), SCHEMA.mentions, URIRef(dbpedia_url)))
# Out:
# 100%|███████████████████████████████████████| 17996/17996 [00:14<00:00, 1247.62it/s]

# %%
g.serialize(destination="/data/peskine/KGs/claim-review-v3.ttl")
# Out:
# <Graph identifier=Ne031d902ea4f4f6ca7f38d68ad7592f3 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Factors

# %% [markdown]
# ## Readability

# %%
def measure_readability(text):
    # The min and max values are defined based on our observation of the data.
    # they could  change in accordance with the dataset circumstances

    # Calculating the readability scores
    value_FRES = measure_FRES(text)

    value_FKGL = measure_FKGL(text)
    value_GFI = measure_GFI(text)
    value_ARI = measure_ARI(text)
    value_DCRS = measure_DCRS(text)
    value_SRF = measure_SRF(text)
    scores = [value_FKGL, value_FKGL, value_GFI, value_ARI, value_DCRS, value_SRF]

    # Averaging the scores
    avg_score = statistics.mean(scores)

    # Normalising the scores to the range 0-100
    min_score = 1
    max_score = 15
    normalised_avg_score = round((avg_score - min_score) / (max_score - min_score) * 100)

    return normalised_avg_score


def measure_FRES(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.flesch_reading_ease(text))

    # Convert the obtained value to the standard score scale (US educational level)
    if value >= 90:
        score = 5
    elif 80 <= value < 90:
        score = 6
    elif 70 <= value < 80:
        score = 7
    elif 65 <= value < 70:
        score = 8
    elif 60 <= value < 65:
        score = 9
    elif 57 <= value < 60:
        score = 10
    elif 54 <= value < 57:
        score = 11
    elif 50 <= value < 54:
        score = 12
    elif 30 <= value < 50:
        score = 13
    elif 10 <= value < 30:
        score = 14
    elif value < 10:
        score = 15

    return score


def measure_FKGL(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.flesch_kincaid_grade(text))
    score = normalise_value_FKGL_ARI_SRF(value)

    return score


def measure_GFI(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.gunning_fog(text))
    # Convert the obtained value to the standard score scale (US educational level)
    if value < 7:
        score = 6
    elif 13 <= value < 17:
        score = 13
    elif value > 17:
        score = 15
    else:
        score = value

    return score


def measure_ARI(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.automated_readability_index(text))
    score = normalise_value_FKGL_ARI_SRF(value)

    return score


def measure_DCRS(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.dale_chall_readability_score(text), 1)
    if value < 5:
        score = 4
    elif 5 <= value < 5.5:
        score = 5
    elif 5.5 <= value < 6:
        score = 6
    elif 6 <= value < 6.5:
        score = 7
    elif 6.5 <= value < 7:
        score = 8
    elif 7 <= value < 7.5:
        score = 9
    elif 7.5 <= value < 8:
        score = 10
    elif 8 <= value < 8.5:
        score = 11
    elif 8.5 <= value < 9:
        score = 12
    elif 9 <= value < 9.5:
        score = 13
    elif 9.5 <= value < 10:
        score = 14
    elif value >= 10:
        score = 15
    return score


def measure_SRF(text):
    # Calculate the value of FRES for the given text
    value = round(textstat.spache_readability(text))
    score = normalise_value_FKGL_ARI_SRF(value)

    return score


def normalise_value_FKGL_ARI_SRF(value):
    # Convert the obtained value to the standard score scale (US educational level)
    if value < 2:
        score = 1
    elif value > 14:
        score = 15
    else:
        score = value

    return score

# %% [markdown]
# ## Cuda

# %%
class CovidTwitterBertClassifier(nn.Module):
    
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes
        self.bert = BertForPreTraining.from_pretrained('digitalepidemiologylab/covid-twitter-bert-v2')    
        self.bert.cls.seq_relationship = nn.Linear(1024, n_classes)

        self.sigmoid = nn.Sigmoid()
        
    def forward(self, input_ids, token_type_ids, input_mask):
        outputs = self.bert(input_ids = input_ids, token_type_ids = token_type_ids, attention_mask = input_mask)

        logits = outputs[1]
        
        return logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla K80'

# %%
tokenizer = AutoTokenizer.from_pretrained('digitalepidemiologylab/covid-twitter-bert')

# %% [markdown]
# ## Emotion

# %%
model_em = CovidTwitterBertClassifier(5)
model_em.load_state_dict(torch.load('/data/peskine/covid-latent/models/emotion_undersampling_CV0_e2_0.622.pth'))
model_em.eval()
model_em.to(device)
# Out:
# CovidTwitterBertClassifier(
#   (bert): BertForPreTraining(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#         (position_embeddings): Embedding(512, 1024)
#         (token_type_embeddings): Embedding(2, 1024)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (12): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (13): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (14): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (15): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (16): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (17): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (18): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (19): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (20): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (21): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (22): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (23): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (cls): BertPreTrainingHeads(
#       (predictions): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=1024, out_features=1024, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=1024, out_features=30522, bias=True)
#       )
#       (seq_relationship): Linear(in_features=1024, out_features=5, bias=True)
#     )
#   )
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Political leaning

# %%
model_pol = CovidTwitterBertClassifier(3)
model_pol.load_state_dict(torch.load('/data/peskine/russian-troll-tweets/models/politics_undersampling_CV0_e24_0.636.pth'))
model_pol.eval()
model_pol.to(device)
# Out:
# CovidTwitterBertClassifier(
#   (bert): BertForPreTraining(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#         (position_embeddings): Embedding(512, 1024)
#         (token_type_embeddings): Embedding(2, 1024)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (12): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (13): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (14): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (15): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (16): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (17): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (18): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (19): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (20): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (21): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (22): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (23): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (cls): BertPreTrainingHeads(
#       (predictions): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=1024, out_features=1024, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=1024, out_features=30522, bias=True)
#       )
#       (seq_relationship): Linear(in_features=1024, out_features=3, bias=True)
#     )
#   )
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Sentiment

# %%
model_sent = CovidTwitterBertClassifier(3)
model_sent.load_state_dict(torch.load('/data/peskine/COVIDSenti/models/senti_CV0_e21_0.769.pth'))
model_sent.eval()
model_sent.to(device)
# Out:
# CovidTwitterBertClassifier(
#   (bert): BertForPreTraining(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#         (position_embeddings): Embedding(512, 1024)
#         (token_type_embeddings): Embedding(2, 1024)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (12): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (13): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (14): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (15): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (16): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (17): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (18): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (19): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (20): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (21): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (22): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (23): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (cls): BertPreTrainingHeads(
#       (predictions): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=1024, out_features=1024, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=1024, out_features=30522, bias=True)
#       )
#       (seq_relationship): Linear(in_features=1024, out_features=3, bias=True)
#     )
#   )
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Conspiracies

# %%
model_con = CovidTwitterBertClassifier(27)
model_con.load_state_dict(torch.load('/data/peskine/mediaeval22/models/task1_twitter_CV3_e21_0.731.pth'))
model_con.eval()
model_con.to(device)
# Out:
# CovidTwitterBertClassifier(
#   (bert): BertForPreTraining(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#         (position_embeddings): Embedding(512, 1024)
#         (token_type_embeddings): Embedding(2, 1024)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (12): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (13): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (14): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (15): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (16): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (17): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (18): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (19): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (20): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (21): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (22): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (23): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=1024, out_features=1024, bias=True)
#                 (key): Linear(in_features=1024, out_features=1024, bias=True)
#                 (value): Linear(in_features=1024, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=4096, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (cls): BertPreTrainingHeads(
#       (predictions): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=1024, out_features=1024, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=1024, out_features=30522, bias=True)
#       )
#       (seq_relationship): Linear(in_features=1024, out_features=27, bias=True)
#     )
#   )
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Compute factors

# %%
def compute_factors(text, compute_emotion=True, compute_political_leaning=True, compute_sentiment=True, compute_conspiracy_theories=True, compute_readability=True):
    emotion, political_bias, sentiment, conspiracy, readability = None, None, None, None, None
    
    MAX_LEN = 128 # < m some tweets will be truncated
    EMOTIONS = ['None', 'Happiness', 'Anger', 'Sadness', 'Fear']
    POLITICAL_BIAS = ['Left', 'Other', 'Right']
    SENTIMENTS = ['Negative', 'Neutral', 'Positive']
    CONSPIRACIES = ['Suppressed Cures', 'Behaviour and mind Control', 'Antivax', 'Fake virus', 'Intentional Pandemic', 'Harmful Radiation', 'Population Reduction', 'New World Order', 'Satanism']
    CONSPIRACY_LEVELS = ['No ', 'Mentioning ', 'Supporting ']
    
    a = tokenizer([text], max_length=MAX_LEN, padding='max_length', truncation=True)
    input_ids = torch.tensor(a['input_ids']).to(device)
    token_type_ids = torch.tensor(a['token_type_ids']).to(device)
    attention_mask = torch.tensor(a['attention_mask']).to(device)
    with torch.no_grad():
        if compute_emotion:
            logits_em = model_em(input_ids, token_type_ids, attention_mask)
        if compute_political_leaning:
            logits_pol = model_pol(input_ids, token_type_ids, attention_mask)
        if compute_sentiment:
            logits_sent = model_sent(input_ids, token_type_ids, attention_mask)
        if compute_conspiracy_theories:
            logits_con = model_con(input_ids, token_type_ids, attention_mask)
        
    emotion = EMOTIONS[logits_em.detach().cpu().numpy()[0].argmax()]
    political_bias = POLITICAL_BIAS[logits_pol.detach().cpu().numpy()[0].argmax()]
    sentiment = SENTIMENTS[logits_sent.detach().cpu().numpy()[0].argmax()]
    conspiracy = [logits_con.detach().cpu().numpy()[0][3*i:3*i+3].argmax() for i in range(0, 9)]
    conspiracies = []
    for i in range(0, 9):
        conspiracies.append(CONSPIRACY_LEVELS[conspiracy[i]]+CONSPIRACIES[i])
        
    if compute_readability:
        readability = measure_readability(text)
    return emotion, political_bias, sentiment, conspiracy, readability

# %% [markdown]
# # Entities

# %%
API_URL = "https://api.dbpedia-spotlight.org/en/annotate"

def extract_dbpedia_entities(s):
    if not s in ['', ' ', '   ']:
        payload = {'text': s}
        a = requests.post(API_URL, 
                     headers={'accept': 'application/json'},
                     data=payload).json()
        return a
    else:
        return []
